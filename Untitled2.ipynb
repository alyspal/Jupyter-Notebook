# %%
# Ho : σ2 = 0,64
# H1 : σ2 > 0,64

# %%
s <- 1.2
sd0 <- 0.8
n <- 50
df <- n-1
alpha <- 0.05
chiSquare_tabel <- qchisq(alpha, df, lower.tail = FALSE) 
chiSquare_tabel
# Out:
# [1] 66.33865

# %%
chiSquare_hitung <- (n-1)*s^2/sd0^2
chiSquare_hitung
# Out:
# [1] 110.25

# %%
# Ho : σ^2(1) = σ^2(2)
# H1 : σ^2(1)  ≠ σ^2(2)

# %%
alpha <- 0.1
n1 <- 25
n2 <- 20
s1 = 4
s2 = 5
df1 <- n1-1
df2 <- n2-1
f_bawah <- qf(0.05, df1,df2)
f_bawah
# Out:
# [1] 0.4902303

# %%
f_atas <- qf(0.95, df1,df2)
f_atas
# Out:
# [1] 2.114143

# %%
f_hitung <- (s1^2*σ^2)/(s2^2*σ^2)
f_hitung
# Out:
# Error in eval(expr, envir, enclos): object 'σ' not found
# Traceback:
