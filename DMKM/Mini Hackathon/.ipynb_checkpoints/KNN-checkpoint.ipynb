# %% [markdown]
# Alya Safadella Putri Akca
# 221910892
# 3SI1

# %% [markdown]
# # Import Data

# %%
from sklearn import neighbors, datasets, model_selection, metrics
import pandas as pd

# reading csv files
TrainData =  pd.read_csv('Train.csv')
TestData =  pd.read_csv('Tes.csv')

# %%
TrainData.head(5)
TestData.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1756/3965195001.py in <module>
# ----> 1 TrainData.head(5)
#       2 TestData.head(5)
#
# NameError: name 'TrainData' is not defined

# %% [markdown]
# **Lihat tabel dan struktur dataset nya terlebih dahulu.**

# %%
# get some rows informations
print(data)

# describe the data
data.describe()
# Out:
#         Sex          Age         Professions           Education Living Area  \
# 0      Male  51-55 years  Medical specialist       Master degree    Downtown
# 1    Female  41-45 years   Non medical staff       Master degree    Downtown
# 2      Male  56-60 years      Medical doctor                 NaN    Downtown
# 3      Male  26-30 years   Non medical staff                 NaN    Downtown
# 4    Female  31-35 years      Medical doctor     Bachelor degree    Downtown
# ..      ...          ...                 ...                 ...         ...
# 444  Female  36-40 years             Midwife     Bachelor degree    Downtown
# 445  Female  46-50 years   Non medical staff     Bachelor degree    Outskirt
# 446  Female  36-40 years               Nurse     Bachelor degree    Downtown
# 447  Female  41-45 years   Non medical staff     Bachelor degree    Downtown
# 448  Female  36-40 years   Non medical staff  Senior high school    Downtown
#
# ...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# **cek skala atau type atribut**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sex                          449 non-null    object
#  1   Age                          449 non-null    object
#  2   Professions                  449 non-null    object
#  3   Education                    447 non-null    object
#  4   Living Area                  449 non-null    object
#  5   1. Swelling                  448 non-null    object
#  6   2. Redness                   448 non-null    object
#  7   3. Itching                   449 non-null    object
#  8   4. Fever                     449 non-null    object
#  9   5. Headache                  449 non-null    object
#  10  6. Muscle Pain               448 non-null    object
#  11  7. Tiredness                 448 non-null    object
#  12  8. Coughing                  449 non-null    object
# ...

# %% [markdown]
# **Cek Apakah masih ada data yang mengandung null**
# dalam dataset ini data yang mengandung null adalah atribut atau baris yang bernilai '?'

# %%
# data['workclass'].value_counts()
for x in data.columns :
  print((data[x] == '?').value_counts())
  print()
# Out:
# False    449
# Name: Sex, dtype: int64
#
# False    449
# Name: Age, dtype: int64
#
# False    449
# Name: Professions, dtype: int64
#
# False    449
# Name: Education, dtype: int64
#
# False    449
# Name: Living Area, dtype: int64
#
# False    449
# Name: 1. Swelling, dtype: int64
#
# False    449
# Name: 2. Redness, dtype: int64
#
# False    449
# Name: 3. Itching, dtype: int64
#
# False    449
# Name: 4. Fever, dtype: int64
#
# False    449
# Name: 5. Headache, dtype: int64
#
# False    449
# Name: 6. Muscle Pain, dtype: int64
#
# False    449
# Name: 7. Tiredness, dtype: int64
#
# False    449
# Name: 8. Coughing, dtype: int64
#
# False    449
# Name: 9. Diarrhea, dtype: int64
#
# False    449
# Name: 10. Nausea and vomiting, dtype: int64
#
# False    449
# Name: 11. Breathlessness, dtype: int64
#
# False    449
# Name: 12. Joint Pain, dtype: int64
#
# False    449
# Name: 13. Fainted, dtype: int64
#
# False    449
# Name: 14. Anaphylactic Reaction, dtype: int64
#
# ...

# %% [markdown]
# **Drop baris dan kolom pada tabel yang mengandung null**

# %%
for x in data.columns:
  data = data[data[x] != '?']

# %%
data = data.dropna()
data = data.drop(columns=['3. Itching'])
data = data.drop(columns=['13. Fainted'])

# %% [markdown]
# **Lihat tabel dan struktur nya**

# %%
# get some rows informations
print(data)

# describe the data
data.describe()
# Out:
#         Sex          Age         Professions           Education Living Area  \
# 0      Male  51-55 years  Medical specialist       Master degree    Downtown
# 1    Female  41-45 years   Non medical staff       Master degree    Downtown
# 4    Female  31-35 years      Medical doctor     Bachelor degree    Downtown
# 6    Female  46-50 years      Medical doctor     Bachelor degree    Downtown
# 7    Female  56-60 years      Medical doctor       Master degree    Downtown
# ..      ...          ...                 ...                 ...         ...
# 444  Female  36-40 years             Midwife     Bachelor degree    Downtown
# 445  Female  46-50 years   Non medical staff     Bachelor degree    Outskirt
# 446  Female  36-40 years               Nurse     Bachelor degree    Downtown
# 447  Female  41-45 years   Non medical staff     Bachelor degree    Downtown
# 448  Female  36-40 years   Non medical staff  Senior high school    Downtown
#
# ...

# %% [markdown]
# **Cek type data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 448
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sex                          444 non-null    object
#  1   Age                          444 non-null    object
#  2   Professions                  444 non-null    object
#  3   Education                    444 non-null    object
#  4   Living Area                  444 non-null    object
#  5   1. Swelling                  444 non-null    object
#  6   2. Redness                   444 non-null    object
#  7   3. Itching                   444 non-null    object
#  8   4. Fever                     444 non-null    object
#  9   5. Headache                  444 non-null    object
#  10  6. Muscle Pain               444 non-null    object
#  11  7. Tiredness                 444 non-null    object
#  12  8. Coughing                  444 non-null    object
# ...

# %% [markdown]
# **Lihat tabel 10 baris pertama**

# %%
data.head(10)
# Out:
#        Sex          Age         Professions        Education Living Area  \
# 0     Male  51-55 years  Medical specialist    Master degree    Downtown
# 1   Female  41-45 years   Non medical staff    Master degree    Downtown
# 4   Female  31-35 years      Medical doctor  Bachelor degree    Downtown
# 6   Female  46-50 years      Medical doctor  Bachelor degree    Downtown
# 7   Female  56-60 years      Medical doctor    Master degree    Downtown
# 8   Female  36-40 years   Non medical staff    Master degree    Downtown
# 9     Male  51-55 years               Nurse    Master degree    Downtown
# 10  Female  56-60 years               Nurse  Bachelor degree    Downtown
# 11  Female  31-35 years      Medical doctor  Bachelor degree    Downtown
# 12  Female  41-45 years               Nurse  Bachelor degree    Downtown
#
#    1. Swelling 2. Redness 3. Itching 4. Fever 5. Headache  ... 8. Coughing  \
# 0           No         No         No       No          No  ...          No
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Import library preprocessing**
# untuk melakukan preprocessing data. mengkodekan variabel/atribut kategorik ke numerik

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

for x in data.columns:
  data[x] = le.fit_transform(data[x])

data.head(10)
# Out:
#     Sex  Age  Professions  Education  Living Area  1. Swelling  2. Redness  \
# 0     1    6            1          2            0            0           0
# 1     0    4            3          2            0            0           0
# 4     0    2            0          0            0            0           0
# 6     0    5            0          0            0            0           0
# 7     0    7            0          2            0            0           0
# 8     0    3            3          2            0            0           0
# 9     1    6            4          2            0            0           0
# 10    0    7            4          0            0            0           0
# 11    0    2            0          0            0            0           0
# 12    0    4            4          0            0            0           0
#
#     3. Itching  4. Fever  5. Headache  ...  8. Coughing  9. Diarrhea  \
# 0            0         0            0  ...            0            0
# ...

# %% [markdown]
# **melakukan standarisasi data**
# melakukan standarisasi data ke dalam bentuk standar normal

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
std_data = pd.DataFrame(scaler.fit_transform(data))

std_data.columns = data.columns
std_data
# Out:
#           Sex       Age  Professions  Education  Living Area  1. Swelling  \
# 0    1.652602  1.725937    -2.224466   1.331986    -0.689263    -0.348155
# 1   -0.605106  0.686865    -0.260922   1.331986    -0.689263    -0.348155
# 2   -0.605106 -0.352208    -3.206239  -0.524849    -0.689263    -0.348155
# 3   -0.605106  1.206401    -3.206239  -0.524849    -0.689263    -0.348155
# 4   -0.605106  2.245474    -3.206239   1.331986    -0.689263    -0.348155
# ..        ...       ...          ...        ...          ...          ...
# 439 -0.605106  0.167328    -1.242694  -0.524849    -0.689263     2.872281
# 440 -0.605106  1.206401    -0.260922  -0.524849     1.450826    -0.348155
# 441 -0.605106  0.167328     0.720851  -0.524849    -0.689263    -0.348155
# 442 -0.605106  0.686865    -0.260922  -0.524849    -0.689263    -0.348155
# 443 -0.605106  0.167328    -0.260922   2.260403    -0.689263    -0.348155
#
#      2. Redness  3. Itching  4. Fever  5. Headache  ...  8. Coughing  \
# ...

# %% [markdown]
# **import library seaborn**
# cek apakah inbalance atau tidak

# %%
import seaborn as sns

sns.set_style('whitegrid')
sns.countplot(x=data['TARGET LABEL (SYMPTOM TIME)'],data=data,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='TARGET LABEL (SYMPTOM TIME)', ylabel='count'>

# %% [markdown]
# **Mengembalikan label salary ke dalam bentuk kategorik dalam angka**

# %%
std_data['TARGET LABEL (SYMPTOM TIME)'] = le.fit_transform(std_data['TARGET LABEL (SYMPTOM TIME)'])
std_data
# Out:
#           Sex       Age  Professions  Education  Living Area  1. Swelling  \
# 0    1.652602  1.725937    -2.224466   1.331986    -0.689263    -0.348155
# 1   -0.605106  0.686865    -0.260922   1.331986    -0.689263    -0.348155
# 2   -0.605106 -0.352208    -3.206239  -0.524849    -0.689263    -0.348155
# 3   -0.605106  1.206401    -3.206239  -0.524849    -0.689263    -0.348155
# 4   -0.605106  2.245474    -3.206239   1.331986    -0.689263    -0.348155
# ..        ...       ...          ...        ...          ...          ...
# 439 -0.605106  0.167328    -1.242694  -0.524849    -0.689263     2.872281
# 440 -0.605106  1.206401    -0.260922  -0.524849     1.450826    -0.348155
# 441 -0.605106  0.167328     0.720851  -0.524849    -0.689263    -0.348155
# 442 -0.605106  0.686865    -0.260922  -0.524849    -0.689263    -0.348155
# 443 -0.605106  0.167328    -0.260922   2.260403    -0.689263    -0.348155
#
#      2. Redness  4. Fever  5. Headache  6. Muscle Pain  7. Tiredness  \
# ...

# %% [markdown]
# **Buat Model K-Neirest Neighbor**

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(std_data.drop(columns=['TARGET LABEL (SYMPTOM TIME)']), std_data[['TARGET LABEL (SYMPTOM TIME)']], test_size=0.33, random_state=69)

model = neighbors.KNeighborsClassifier(n_neighbors=3)

print(X_train)
print(y_train)

model.fit(X_train, y_train)

predicted = model.predict(X_test)
print(predicted)

print(metrics.confusion_matrix(y_test, predicted))
print(metrics.accuracy_score(y_test, predicted))
# Out:
#           Sex       Age  Professions  Education  Living Area  1. Swelling  \
# 118  1.652602 -0.871745    -0.260922   0.403569    -0.689263    -0.348155
# 72  -0.605106 -0.352208    -1.242694  -0.524849     1.450826    -0.348155
# 255 -0.605106  1.725937    -0.260922  -0.524849     1.450826    -0.348155
# 1   -0.605106  0.686865    -0.260922   1.331986    -0.689263    -0.348155
# 429 -0.605106 -0.352208    -1.242694   1.331986    -0.689263    -0.348155
# ..        ...       ...          ...        ...          ...          ...
# 439 -0.605106  0.167328    -1.242694  -0.524849    -0.689263     2.872281
# 90  -0.605106  1.725937     0.720851  -0.524849     1.450826    -0.348155
# 107 -0.605106 -0.871745    -0.260922   2.260403    -0.689263    -0.348155
# 203 -0.605106 -0.352208     0.720851  -0.524849    -0.689263    -0.348155
# 54  -0.605106 -0.352208    -1.242694  -0.524849    -0.689263    -0.348155
#
#      2. Redness  4. Fever  5. Headache  6. Muscle Pain  7. Tiredness  \
# ...

# %% [markdown]
# **Cek konfusion matriks**

# %%
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, predicted, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# **Menghitung Accuracy,Precision, Recall, dan F1-Score**

# %%
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.56      0.58        36
#            1       0.54      0.38      0.44        53
#            2       0.00      0.00      0.00         3
#            3       0.57      0.80      0.67        55
#
#     accuracy                           0.57       147
#    macro avg       0.43      0.43      0.42       147
# weighted avg       0.56      0.57      0.55       147
# D:\WORK\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# **Cek akurasi model**

# %%
model.score(X_test, y_test)
# Out:
# 0.5714285714285714

# %% [markdown]
# **Lakukan Cross Validation**
# sebelum itu lakukan import library cross_val_score

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

#create a new KNN model
knn_cv = neighbors.KNeighborsClassifier(n_neighbors=3)

#train model with cv of 5 
cv_scores = cross_val_score(knn_cv, X_train, y_train, cv=5)

#print each cv score (accuracy) and average them
print(cv_scores)
print('cv_scores mean:{}'.format(np.mean(cv_scores)))
# Out:
# [0.55       0.5        0.50847458 0.55932203 0.52542373]
# cv_scores mean:0.5286440677966102
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %% [markdown]
# **Cek korelasi antar atribut**

# %%
print(std_data.drop(columns=['TARGET LABEL (SYMPTOM TIME)']).corr)
# Out:
# <bound method DataFrame.corr of           Sex       Age  Professions  Education  Living Area  1. Swelling  \
# 0    1.652602  1.725937    -2.224466   1.331986    -0.689263    -0.348155
# 1   -0.605106  0.686865    -0.260922   1.331986    -0.689263    -0.348155
# 2   -0.605106 -0.352208    -3.206239  -0.524849    -0.689263    -0.348155
# 3   -0.605106  1.206401    -3.206239  -0.524849    -0.689263    -0.348155
# 4   -0.605106  2.245474    -3.206239   1.331986    -0.689263    -0.348155
# ..        ...       ...          ...        ...          ...          ...
# 439 -0.605106  0.167328    -1.242694  -0.524849    -0.689263     2.872281
# 440 -0.605106  1.206401    -0.260922  -0.524849     1.450826    -0.348155
# 441 -0.605106  0.167328     0.720851  -0.524849    -0.689263    -0.348155
# 442 -0.605106  0.686865    -0.260922  -0.524849    -0.689263    -0.348155
# 443 -0.605106  0.167328    -0.260922   2.260403    -0.689263    -0.348155
#
# ...

# %% [markdown]
# **Lihat model Korelasi antar atribut**

# %%
# plotting correlation heatmap
dataplot = sns.heatmap(std_data.drop(columns=['TARGET LABEL (SYMPTOM TIME)']).corr(), cmap="YlGnBu", annot=False)
  
# displaying heatmap
plt.show()

# %% [markdown]
# **Lakukan GridSearchCV untuk menemukan parameter terbaik**
# Dimana tujuan itu untuk mencari nilai k, menentukan metode kemiripan yang tepat, dan menggunkan bobot uniform atau distance dengan cross validation 10

# %%
from sklearn.model_selection import GridSearchCV

#List Hyperparameters to tune
n_neighbors = list(range(1,10))
p = [1,2]
weights = ['uniform','distance']

#convert to dictionary
hyperparameters = dict(n_neighbors=n_neighbors, p=p, weights=weights)

#Making model
clf = GridSearchCV(model, hyperparameters, cv=10)
best_model = clf.fit(X_train, y_train)

#Best Hyperparameters Value
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
print('Best weights:', best_model.best_estimator_.get_params()['weights'])

#Predict testing set
predicted2 = best_model.predict(X_test)

#Check performance using accuracy
print(accuracy_score(y_test, predicted2))
# Out:
# D:\WORK\anaconda\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 6 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# D:\WORK\anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %% [markdown]
# **Cek Akurasi model yang direkomendasikan dari parameter yang telah ditentukan**

# %%
best_model.score(X_test, y_test)
# Out:
# 0.5306122448979592

# %% [markdown]
# **Cek Konfusion Matrix**

# %%
predicted3 = best_model.predict(X_test)

cm = confusion_matrix(y_test, predicted3, labels=best_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot()
plt.show()
