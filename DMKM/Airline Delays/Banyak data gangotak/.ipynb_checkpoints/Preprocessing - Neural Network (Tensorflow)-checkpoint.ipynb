# %% [markdown]
# # Input packages and datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import imblearn
import tensorflow as tf
import keras

from keras.utils import np_utils
from tensorflow.keras import layers, models, utils, datasets, losses
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras.callbacks import LearningRateScheduler, History
from sklearn.utils import shuffle
from sklearn import svm, preprocessing, neighbors, datasets, model_selection, metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
data = pd.read_csv('busiest_airline_delays.csv')

# %% [raw]
# from pandas_profiling import ProfileReport
# profile = ProfileReport(data)
# profile.to_file("mantab.html")

# %% [markdown]
# # Preprocessing

# %%
data.head()
# Out:
#    MONTH  DAY_OF_WEEK  DEP_DEL15  DISTANCE_GROUP      DEP_BLOCK  \
# 0      1            3          0               5        MORNING
# 1      1            3          0               3        MORNING
# 2      1            3          0               9        MORNING
# 3      1            3          0               1  EARLY_MORNING
# 4      1            3          0               2        MORNING
#
#    SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0               1                 229              142
# 1               1                 229              120
# 2               1                 229              142
# 3               1                   4              128
# 4               1                 229               50
#
#              CARRIER_NAME  AIRPORT_FLIGHTS_MONTH  ...  PLANE_AGE  \
# 0   United Air Lines Inc.                  32102  ...         19
# 1   United Air Lines Inc.                  32102  ...         22
# 2   United Air Lines Inc.                  32102  ...         24
# 3  American Airlines Inc.                  32102  ...         20
# 4   SkyWest Airlines Inc.                  32102  ...         21
#
#    DEPARTING_AIRPORT  LATITUDE  LONGITUDE  PREVIOUS_AIRPORT  PRCP  SNOW SNWD  \
# 0  Atlanta Municipal    33.641    -84.427              NONE   0.0   0.0  0.0
# 1  Atlanta Municipal    33.641    -84.427              NONE   0.0   0.0  0.0
# 2  Atlanta Municipal    33.641    -84.427              NONE   0.0   0.0  0.0
# 3  Atlanta Municipal    33.641    -84.427              NONE   0.0   0.0  0.0
# 4  Atlanta Municipal    33.641    -84.427              NONE   0.0   0.0  0.0
#
#    TMAX  AWND
# 0  72.0  4.47
# 1  72.0  4.47
# 2  72.0  4.47
# 3  72.0  4.47
# 4  72.0  4.47
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120894 entries, 0 to 120893
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   MONTH                          120894 non-null  int64
#  1   DAY_OF_WEEK                    120894 non-null  int64
#  2   DEP_DEL15                      120894 non-null  int64
#  3   DISTANCE_GROUP                 120894 non-null  int64
#  4   DEP_BLOCK                      120894 non-null  object
#  5   SEGMENT_NUMBER                 120894 non-null  int64
#  6   CONCURRENT_FLIGHTS             120894 non-null  int64
#  7   NUMBER_OF_SEATS                120894 non-null  int64
#  8   CARRIER_NAME                   120894 non-null  object
#  9   AIRPORT_FLIGHTS_MONTH          120894 non-null  int64
#  10  AIRLINE_FLIGHTS_MONTH          120894 non-null  int64
#  11  AIRLINE_AIRPORT_FLIGHTS_MONTH  120894 non-null  int64
#  12  AVG_MONTHLY_PASS_AIRPORT       120894 non-null  int64
#  13  AVG_MONTHLY_PASS_AIRLINE       120894 non-null  int64
#  14  FLT_ATTENDANTS_PER_PASS        120894 non-null  float64
#  15  GROUND_SERV_PER_PASS           120894 non-null  float64
#  16  PLANE_AGE                      120894 non-null  int64
#  17  DEPARTING_AIRPORT              120894 non-null  object
#  18  LATITUDE                       120894 non-null  float64
#  19  LONGITUDE                      120894 non-null  float64
#  20  PREVIOUS_AIRPORT               120894 non-null  object
#  21  PRCP                           120894 non-null  float64
#  22  SNOW                           120894 non-null  float64
#  23  SNWD                           120894 non-null  float64
#  24  TMAX                           120894 non-null  float64
#  25  AWND                           120894 non-null  float64
# dtypes: float64(9), int64(13), object(4)
# memory usage: 24.0+ MB

# %%
data.describe()
# Out:
#           MONTH    DAY_OF_WEEK      DEP_DEL15  DISTANCE_GROUP  SEGMENT_NUMBER  \
# count  120894.0  120894.000000  120894.000000   120894.000000   120894.000000
# mean        1.0       3.942677       0.149710        3.353525        3.211152
# std         0.0       1.910102       0.356788        1.855241        1.718627
# min         1.0       1.000000       0.000000        1.000000        1.000000
# 25%         1.0       2.000000       0.000000        2.000000        2.000000
# 50%         1.0       4.000000       0.000000        3.000000        3.000000
# 75%         1.0       5.000000       0.000000        4.000000        4.000000
# max         1.0       7.000000       1.000000       11.000000       11.000000
#
#        CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  AIRPORT_FLIGHTS_MONTH  \
# count       120894.000000    120894.000000          120894.000000
# mean           177.968783       127.222674           24984.998114
# std             52.524855        50.946997            4667.824038
# min              1.000000        44.000000           19902.000000
# 25%            156.000000        76.000000           20193.000000
# 50%            182.000000       142.000000           23873.000000
# 75%            213.000000       172.000000           32102.000000
# max            286.000000       337.000000           32102.000000
#
#        AIRLINE_FLIGHTS_MONTH  AIRLINE_AIRPORT_FLIGHTS_MONTH  ...  \
# count          120894.000000                  120894.000000  ...
# mean            58978.630974                    7537.814565  ...
# std             27722.923436                    6050.361247  ...
# min              7688.000000                       1.000000  ...
# 25%             25366.000000                    3787.000000  ...
# 50%             69699.000000                    5347.000000  ...
# 75%             80026.000000                   11786.000000  ...
# max            107849.000000                   19461.000000  ...
#
#        FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS      PLANE_AGE  \
# count            120894.000000         120894.000000  120894.000000
# mean                  0.000612              0.000723      11.730557
# std                   0.000532              0.000263       7.522912
# min                   0.000000              0.000033       0.000000
# 25%                   0.000170              0.000492       4.000000
# 50%                   0.000504              0.000792      13.000000
# 75%                   0.000768              0.000911      18.000000
# max                   0.001759              0.001265      32.000000
#
#             LATITUDE      LONGITUDE           PRCP           SNOW  \
# count  120894.000000  120894.000000  120894.000000  120894.000000
# mean       36.489558     -90.471664       0.126495       0.042920
# std         3.600088       8.318211       0.307733       0.262952
# min        32.894000    -104.880000       0.000000       0.000000
# 25%        33.641000     -97.030000       0.000000       0.000000
# 50%        35.219000     -87.906000       0.000000       0.000000
# 75%        39.774000     -84.427000       0.020000       0.000000
# max        41.978000     -80.936000       1.910000       3.100000
#
#                 SNWD           TMAX           AWND
# count  120894.000000  120894.000000  120894.000000
# mean        0.144341      51.493838       8.819766
# std         0.486133      11.645643       3.449294
# min         0.000000      19.000000       2.680000
# 25%         0.000000      42.000000       6.040000
# 50%         0.000000      53.000000       8.050000
# 75%         0.000000      60.000000      11.180000
# max         2.000000      79.000000      25.050000
#
# [8 rows x 22 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x=data['DEP_DEL15'],data=data)
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
data = data.drop_duplicates()
data = data.drop(columns=['MONTH','LATITUDE','LONGITUDE'])
data = data.drop(columns=['CONCURRENT_FLIGHTS','AIRPORT_FLIGHTS_MONTH','AIRLINE_FLIGHTS_MONTH'])
data.head()
# Out:
#    DAY_OF_WEEK  DEP_DEL15  DISTANCE_GROUP      DEP_BLOCK  SEGMENT_NUMBER  \
# 0            3          0               5        MORNING               1
# 1            3          0               3        MORNING               1
# 2            3          0               9        MORNING               1
# 3            3          0               1  EARLY_MORNING               1
# 4            3          0               2        MORNING               1
#
#    NUMBER_OF_SEATS            CARRIER_NAME  AIRLINE_AIRPORT_FLIGHTS_MONTH  \
# 0              142   United Air Lines Inc.                            361
# 1              120   United Air Lines Inc.                            361
# 2              142   United Air Lines Inc.                            361
# 3              128  American Airlines Inc.                            892
# 4               50   SkyWest Airlines Inc.                           2048
#
#    AVG_MONTHLY_PASS_AIRPORT  AVG_MONTHLY_PASS_AIRLINE  \
# 0                    816174                   1539321
# 1                    816174                   1539321
# 2                    816174                   1539321
# 3                    816174                   2286836
# 4                    816174                    698248
#
#    FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS  PLANE_AGE  \
# 0                 0.001402              0.001265         19
# 1                 0.001402              0.001265         22
# 2                 0.001402              0.001265         24
# 3                 0.000504              0.000911         20
# 4                 0.000170              0.000492         21
#
#    DEPARTING_AIRPORT PREVIOUS_AIRPORT  PRCP  SNOW  SNWD  TMAX  AWND
# 0  Atlanta Municipal             NONE   0.0   0.0   0.0  72.0  4.47
# 1  Atlanta Municipal             NONE   0.0   0.0   0.0  72.0  4.47
# 2  Atlanta Municipal             NONE   0.0   0.0   0.0  72.0  4.47
# 3  Atlanta Municipal             NONE   0.0   0.0   0.0  72.0  4.47
# 4  Atlanta Municipal             NONE   0.0   0.0   0.0  72.0  4.47

# %% [markdown]
# # Neural network

# %%
# Encode labels in columns
label_encoder = preprocessing.LabelEncoder()
data['DEP_BLOCK']= label_encoder.fit_transform(data['DEP_BLOCK'])
data['CARRIER_NAME']= label_encoder.fit_transform(data['CARRIER_NAME'])
data['DEPARTING_AIRPORT']= label_encoder.fit_transform(data['DEPARTING_AIRPORT'])
data['PREVIOUS_AIRPORT']= label_encoder.fit_transform(data['PREVIOUS_AIRPORT'])

# %% [markdown]
# ## Split Data

# %%
# data_feat yang khusus hanya akan berisi nilai-nilai atribut/fitur/variabel saja.
# data_target yang khusus hanya akan berisi label/kelas/target 
df_feat = data.drop('DEP_DEL15',axis=1) 
df_feat.head()
# Out:
#    DAY_OF_WEEK  DISTANCE_GROUP  DEP_BLOCK  SEGMENT_NUMBER  NUMBER_OF_SEATS  \
# 0            3               5          5               1              142
# 1            3               3          5               1              120
# 2            3               9          5               1              142
# 3            3               1          1               1              128
# 4            3               2          5               1               50
#
#    CARRIER_NAME  AIRLINE_AIRPORT_FLIGHTS_MONTH  AVG_MONTHLY_PASS_AIRPORT  \
# 0            15                            361                    816174
# 1            15                            361                    816174
# 2            15                            361                    816174
# 3             2                            892                    816174
# 4            12                           2048                    816174
#
#    AVG_MONTHLY_PASS_AIRLINE  FLT_ATTENDANTS_PER_PASS  GROUND_SERV_PER_PASS  \
# 0                   1539321                 0.001402              0.001265
# 1                   1539321                 0.001402              0.001265
# 2                   1539321                 0.001402              0.001265
# 3                   2286836                 0.000504              0.000911
# 4                    698248                 0.000170              0.000492
#
#    PLANE_AGE  DEPARTING_AIRPORT  PREVIOUS_AIRPORT  PRCP  SNOW  SNWD  TMAX  \
# 0         19                  0               178   0.0   0.0   0.0  72.0
# 1         22                  0               178   0.0   0.0   0.0  72.0
# 2         24                  0               178   0.0   0.0   0.0  72.0
# 3         20                  0               178   0.0   0.0   0.0  72.0
# 4         21                  0               178   0.0   0.0   0.0  72.0
#
#    AWND
# 0  4.47
# 1  4.47
# 2  4.47
# 3  4.47
# 4  4.47

# %%
# df_target yang khusus hanya akan berisi label/kelas/target, yaitu apakah positif kanker ganas atau tidak
df_target = data['DEP_DEL15'] 
df_target.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: DEP_DEL15, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df_feat, df_target, test_size=0.30, random_state=0)
print("Jumlah Training Data : ", len(X_train), " | Jumlah Test Data : ", len(X_test))
# Out:
# Jumlah Training Data :  83811  | Jumlah Test Data :  35920

# %%
oversample = imblearn.over_sampling.SMOTE()
X_train, y_train = oversample.fit_resample(X_train, y_train)
y_train.value_counts()
# Out:
# 0    71137
# 1    71137
# Name: DEP_DEL15, dtype: int64

# %% [markdown]
# ## Transformasi data

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
tf.random.set_seed(42)


model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    loss=tf.keras.losses.binary_crossentropy,
    optimizer=tf.keras.optimizers.Adam(lr=0.03),
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

history = model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6214 - accuracy: 0.6663 - precision: 0.6528 - recall: 0.7106
# Epoch 2/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6896 - accuracy: 0.5173 - precision: 0.5165 - recall: 0.5428
# Epoch 3/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5004 - precision: 0.5004 - recall: 0.5180
# Epoch 4/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.4978 - precision: 0.4978 - recall: 0.5068: 8s - loss: 0.69 - ETA: 4s - loss: 0.6940 - accuracy - ETA: 2s - loss: 0.6939 - accuracy: 0.4
# Epoch 5/50
# 4447/4447 [==============================] - 9s 2ms/step - loss: 0.6937 - accuracy: 0.5007 - precision: 0.5007 - recall: 0.5001
# Epoch 6/50
# 4447/4447 [==============================] - 9s 2ms/step - loss: 0.6938 - accuracy: 0.4974 - precision: 0.4976 - recall: 0.5453
# Epoch 7/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.5006 - precision: 0.5006 - recall: 0.4950
# Epoch 8/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.5000 - precision: 0.5000 - recall: 0.4957:
# Epoch 9/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5012 - precision: 0.5012 - recall: 0.5158
# Epoch 10/50
# 4447/4447 [==============================] - 9s 2ms/step - loss: 0.6938 - accuracy: 0.4988 - precision: 0.4989 - recall: 0.5294
# Epoch 11/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6937 - accuracy: 0.5008 - precision: 0.5008 - recall: 0.5011: 5s - loss: 0.69 - ETA: 2s - loss: 0.6937 - accu - ETA: 0s - loss: 0.6938 - accuracy: 0.5005 - precision: 0.5006 - recall: 0
# Epoch 12/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6939 - accuracy: 0.5003 - precision: 0.5003 - recall: 0.4792: 4s - loss: 0.6940 - accuracy: - ETA: 2s - loss: 0.6940 - accuracy: 0.4990 - precision: 0.4996 - recal - ETA: 2s - loss: 0.6940 - accuracy: 0
# Epoch 13/50
# 4447/4447 [==============================] - 9s 2ms/step - loss: 0.6939 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4879A: 1s - loss: 0.6938 - accuracy: 0.4978 - precision: 0.4977 - rec - ETA: 0s - loss: 0.6938 - accuracy: 0.4979 - precision: 0.4982
# Epoch 14/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.4997 - precision: 0.4997 - recall: 0.4974
# Epoch 15/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5003 - precision: 0.5003 - recall: 0.4783: 6s - loss: 0.6936 - accuracy: 0
# Epoch 16/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.4991 - precision: 0.4991 - recall: 0.4899
# Epoch 17/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.4997 - precision: 0.4997 - recall: 0.5159
# Epoch 18/50
# 4447/4447 [==============================] - 12s 3ms/step - loss: 0.6937 - accuracy: 0.5002 - precision: 0.5002 - recall: 0.4806
# Epoch 19/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.5009 - precision: 0.5009 - recall: 0.5076
# Epoch 20/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.4978 - precision: 0.4978 - recall: 0.5041
# Epoch 21/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.5006 - precision: 0.5007 - recall: 0.4797: 0s - loss: 0.6939 - accuracy: 0.5006 - precision: 0.5008 - re
# Epoch 22/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5004 - precision: 0.5005 - recall: 0.4998
# Epoch 23/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.4982 - precision: 0.4982 - recall: 0.4910
# Epoch 24/50
# 4447/4447 [==============================] - 13s 3ms/step - loss: 0.6939 - accuracy: 0.4983 - precision: 0.4984 - recall: 0.5066
# Epoch 25/50
# 4447/4447 [==============================] - 13s 3ms/step - loss: 0.6938 - accuracy: 0.5008 - precision: 0.5008 - recall: 0.5024
# Epoch 26/50
# 4447/4447 [==============================] - 13s 3ms/step - loss: 0.6937 - accuracy: 0.4996 - precision: 0.4996 - recall: 0.4909: 0s - loss: 0.6937 - accuracy: 0.4996 - precision: 0.4998
# Epoch 27/50
# 4447/4447 [==============================] - 13s 3ms/step - loss: 0.6939 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.5079
# Epoch 28/50
# 4447/4447 [==============================] - 14s 3ms/step - loss: 0.6938 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.5016
# Epoch 29/50
# 4447/4447 [==============================] - 14s 3ms/step - loss: 0.6937 - accuracy: 0.5015 - precision: 0.5015 - recall: 0.5339
# Epoch 30/50
# 4447/4447 [==============================] - 12s 3ms/step - loss: 0.6937 - accuracy: 0.5002 - precision: 0.5002 - recall: 0.4885
# Epoch 31/50
# 4447/4447 [==============================] - 13s 3ms/step - loss: 0.6938 - accuracy: 0.5013 - precision: 0.5013 - recall: 0.4977
# Epoch 32/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.4999 - precision: 0.4999 - recall: 0.5166
# Epoch 33/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.4981 - precision: 0.4981 - recall: 0.4999
# Epoch 34/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.4999 - precision: 0.4999 - recall: 0.4999
# Epoch 35/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6937 - accuracy: 0.5007 - precision: 0.5008 - recall: 0.4967
# Epoch 36/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.4990 - precision: 0.4991 - recall: 0.5155
# Epoch 37/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5010 - precision: 0.5009 - recall: 0.5115
# Epoch 38/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.5151: 1s - loss: 0.6938 - accuracy: 0.4995
# Epoch 39/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5015 - precision: 0.5015 - recall: 0.5062
# Epoch 40/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5001 - precision: 0.5001 - recall: 0.4772
# Epoch 41/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.4995 - precision: 0.4995 - recall: 0.5261
# Epoch 42/50
# 4447/4447 [==============================] - 12s 3ms/step - loss: 0.6938 - accuracy: 0.5015 - precision: 0.5014 - recall: 0.5228
# Epoch 43/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6939 - accuracy: 0.4978 - precision: 0.4977 - recall: 0.4879
# Epoch 44/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6937 - accuracy: 0.5015 - precision: 0.5015 - recall: 0.4839
# Epoch 45/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5008 - precision: 0.5007 - recall: 0.5298
# Epoch 46/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6937 - accuracy: 0.4994 - precision: 0.4994 - recall: 0.4965
# Epoch 47/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6939 - accuracy: 0.4989 - precision: 0.4988 - recall: 0.4795
# Epoch 48/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6937 - accuracy: 0.5013 - precision: 0.5014 - recall: 0.4705
# Epoch 49/50
# 4447/4447 [==============================] - 11s 2ms/step - loss: 0.6938 - accuracy: 0.5003 - precision: 0.5003 - recall: 0.4985
# Epoch 50/50
# 4447/4447 [==============================] - 10s 2ms/step - loss: 0.6938 - accuracy: 0.5003 - precision: 0.5003 - recall: 0.4918

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['figure.figsize'] = (18, 8)
rcParams['axes.spines.top'] = False
rcParams['axes.spines.right'] = False

# %%
plt.plot(
    np.arange(1, 51), 
    history.history['loss'], label='Loss'
)
plt.plot(
    np.arange(1, 51), 
    history.history['accuracy'], label='Accuracy'
)
plt.plot(
    np.arange(1, 51), 
    history.history['precision'], label='Precision'
)
plt.plot(
    np.arange(1, 51), 
    history.history['recall'], label='Recall'
)
plt.title('Evaluation metrics', size=20)
plt.xlabel('Epoch', size=14)
plt.legend();

# %%
y_pred = model.predict(X_test_scaled)
y_pred_classes = [ 1 if prob > 0.531 else 0 for prob in np.ravel(y_pred)]
print(confusion_matrix(y_test, y_pred_classes))
# Out:
# [[30535     0]
#  [ 5385     0]]

# %%
print(classification_report(y_test, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     30535
#            1       0.15      1.00      0.26      5385
#
#     accuracy                           0.15     35920
#    macro avg       0.07      0.50      0.13     35920
# weighted avg       0.02      0.15      0.04     35920
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
