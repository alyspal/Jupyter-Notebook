# %% [markdown]
# # Input packages and datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing

# %%
data = pd.read_csv('busiest_airport_airline_delays.csv')

# %% [raw]
# DAY_OF_WEEK:					Day of Week
# DEP_DEL15: 						TARGET Binary of a departure delay over 15 minutes (1 is yes)
# DISTANCE_GROUP:					Distance group to be flown by departing aircraft
# DEP_BLOCK:						Departure block
# SEGMENT_NUMBER:					The segment that this tail number is on for the day
# CONCURRENT_FLIGHTS:				Concurrent flights leaving from the airport in the same departure block
# NUMBER_OF_SEATS:				Number of seats on the aircraft
# CARRIER_NAME:					Carrier
# AIRPORT_FLIGHTS_MONTH:			Avg Airport Flights per Month
# AIRLINE_FLIGHTS_MONTH:			Avg Airline Flights per Month
# AIRLINE_AIRPORT_FLIGHTS_MONTH:	Avg Flights per month for Airline AND Airport
# AVG_MONTHLY_PASS_AIRPORT:		Avg Passengers for the departing airport for the month
# AVG_MONTHLY_PASS_AIRLINE:		Avg Passengers for airline for month
# FLT_ATTENDANTS_PER_PASS:		Flight attendants per passenger for airline
# GROUND_SERV_PER_PASS:			Ground service employees (service desk) per passenger for airline
# PLANE_AGE:						Age of departing aircraft
# DEPARTING_AIRPORT:				Departing Airport
# LATITUDE:						Latitude of departing airport
# LONGITUDE:						Longitude of departing airport
# PREVIOUS_AIRPORT:				Previous airport that aircraft departed from
# PRCP:							Inches of precipitation for day
# SNOW:							Inches of snowfall for day
# SNWD:							Inches of snow on ground for day
# TMAX:							Max temperature for day
# AWND:							Max wind speed for day

# %% [markdown]
# # Preprocessing

# %%
data.nunique()
# Out:
# DAY_OF_WEEK                        7
# DEP_DEL15                          2
# DISTANCE_GROUP                    11
# DEP_BLOCK                          6
# SEGMENT_NUMBER                    11
# CONCURRENT_FLIGHTS               206
# NUMBER_OF_SEATS                   70
# CARRIER_NAME                      16
# AIRPORT_FLIGHTS_MONTH              5
# AIRLINE_FLIGHTS_MONTH             16
# AIRLINE_AIRPORT_FLIGHTS_MONTH     63
# AVG_MONTHLY_PASS_AIRPORT           5
# AVG_MONTHLY_PASS_AIRLINE          16
# FLT_ATTENDANTS_PER_PASS           13
# GROUND_SERV_PER_PASS              16
# PLANE_AGE                         32
# DEPARTING_AIRPORT                  5
# LATITUDE                           5
# LONGITUDE                          5
# PREVIOUS_AIRPORT                 285
# PRCP                              35
# SNOW                               8
# SNWD                               3
# TMAX                              43
# AWND                              56
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120894 entries, 0 to 120893
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DAY_OF_WEEK                    120894 non-null  int64
#  1   DEP_DEL15                      120894 non-null  int64
#  2   DISTANCE_GROUP                 120894 non-null  int64
#  3   DEP_BLOCK                      120894 non-null  object
#  4   SEGMENT_NUMBER                 120894 non-null  int64
#  5   CONCURRENT_FLIGHTS             120894 non-null  int64
#  6   NUMBER_OF_SEATS                120894 non-null  int64
#  7   CARRIER_NAME                   120894 non-null  object
#  8   AIRPORT_FLIGHTS_MONTH          120894 non-null  int64
#  9   AIRLINE_FLIGHTS_MONTH          120894 non-null  int64
#  10  AIRLINE_AIRPORT_FLIGHTS_MONTH  120894 non-null  int64
#  11  AVG_MONTHLY_PASS_AIRPORT       120894 non-null  int64
#  12  AVG_MONTHLY_PASS_AIRLINE       120894 non-null  int64
#  13  FLT_ATTENDANTS_PER_PASS        120894 non-null  float64
#  14  GROUND_SERV_PER_PASS           120894 non-null  float64
#  15  PLANE_AGE                      120894 non-null  int64
#  16  DEPARTING_AIRPORT              120894 non-null  object
#  17  LATITUDE                       120894 non-null  float64
#  18  LONGITUDE                      120894 non-null  float64
#  19  PREVIOUS_AIRPORT               120894 non-null  object
#  20  PRCP                           120894 non-null  float64
#  21  SNOW                           120894 non-null  float64
#  22  SNWD                           120894 non-null  float64
#  23  TMAX                           120894 non-null  float64
#  24  AWND                           120894 non-null  float64
# dtypes: float64(9), int64(12), object(4)
# memory usage: 23.1+ MB

# %%
data.describe()
# Out:
#          DAY_OF_WEEK      DEP_DEL15  DISTANCE_GROUP  SEGMENT_NUMBER  \
# count  120894.000000  120894.000000   120894.000000   120894.000000
# mean        3.942677       0.149710        3.353525        3.211152
# std         1.910102       0.356788        1.855241        1.718627
# min         1.000000       0.000000        1.000000        1.000000
# 25%         2.000000       0.000000        2.000000        2.000000
# 50%         4.000000       0.000000        3.000000        3.000000
# 75%         5.000000       0.000000        4.000000        4.000000
# max         7.000000       1.000000       11.000000       11.000000
#
#        CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  AIRPORT_FLIGHTS_MONTH  \
# count       120894.000000    120894.000000          120894.000000
# mean           177.968783       127.222674           24984.998114
# std             52.524855        50.946997            4667.824038
# min              1.000000        44.000000           19902.000000
# 25%            156.000000        76.000000           20193.000000
# 50%            182.000000       142.000000           23873.000000
# 75%            213.000000       172.000000           32102.000000
# max            286.000000       337.000000           32102.000000
#
#        AIRLINE_FLIGHTS_MONTH  AIRLINE_AIRPORT_FLIGHTS_MONTH  \
# count          120894.000000                  120894.000000
# mean            58978.630974                    7537.814565
# std             27722.923436                    6050.361247
# min              7688.000000                       1.000000
# 25%             25366.000000                    3787.000000
# 50%             69699.000000                    5347.000000
# 75%             80026.000000                   11786.000000
# max            107849.000000                   19461.000000
#
#        AVG_MONTHLY_PASS_AIRPORT  ...  FLT_ATTENDANTS_PER_PASS  \
# count             120894.000000  ...            120894.000000
# mean              593673.915852  ...                 0.000612
# std               142124.197550  ...                 0.000532
# min               413854.000000  ...                 0.000000
# 25%               516205.000000  ...                 0.000170
# 50%               541843.000000  ...                 0.000504
# 75%               816174.000000  ...                 0.000768
# max               816174.000000  ...                 0.001759
#
#        GROUND_SERV_PER_PASS      PLANE_AGE       LATITUDE      LONGITUDE  \
# count         120894.000000  120894.000000  120894.000000  120894.000000
# mean               0.000723      11.730557      36.489558     -90.471664
# std                0.000263       7.522912       3.600088       8.318211
# min                0.000033       0.000000      32.894000    -104.880000
# 25%                0.000492       4.000000      33.641000     -97.030000
# 50%                0.000792      13.000000      35.219000     -87.906000
# 75%                0.000911      18.000000      39.774000     -84.427000
# max                0.001265      32.000000      41.978000     -80.936000
#
#                 PRCP           SNOW           SNWD           TMAX  \
# count  120894.000000  120894.000000  120894.000000  120894.000000
# mean        0.126495       0.042920       0.144341      51.493838
# std         0.307733       0.262952       0.486133      11.645643
# min         0.000000       0.000000       0.000000      19.000000
# 25%         0.000000       0.000000       0.000000      42.000000
# 50%         0.000000       0.000000       0.000000      53.000000
# 75%         0.020000       0.000000       0.000000      60.000000
# max         1.910000       3.100000       2.000000      79.000000
#
#                 AWND
# count  120894.000000
# mean        8.819766
# std         3.449294
# min         2.680000
# 25%         6.040000
# 50%         8.050000
# 75%        11.180000
# max        25.050000
#
# [8 rows x 21 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x=data['DEP_DEL15'],data=data)
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
data = data.drop_duplicates()
data = data.drop(columns=['LATITUDE','LONGITUDE'])
data.head()
# Out:
#    DAY_OF_WEEK  DEP_DEL15  DISTANCE_GROUP      DEP_BLOCK  SEGMENT_NUMBER  \
# 0            3          0               5        MORNING               1
# 1            3          0               3        MORNING               1
# 2            3          0               9        MORNING               1
# 3            3          0               1  EARLY_MORNING               1
# 4            3          0               2        MORNING               1
#
#    CONCURRENT_FLIGHTS  NUMBER_OF_SEATS            CARRIER_NAME  \
# 0                 229              142   United Air Lines Inc.
# 1                 229              120   United Air Lines Inc.
# 2                 229              142   United Air Lines Inc.
# 3                   4              128  American Airlines Inc.
# 4                 229               50   SkyWest Airlines Inc.
#
#    AIRPORT_FLIGHTS_MONTH  AIRLINE_FLIGHTS_MONTH  ...  FLT_ATTENDANTS_PER_PASS  \
# 0                  32102                  48104  ...                 0.001402
# 1                  32102                  48104  ...                 0.001402
# 2                  32102                  48104  ...                 0.001402
# 3                  32102                  75591  ...                 0.000504
# 4                  32102                  69699  ...                 0.000170
#
#    GROUND_SERV_PER_PASS  PLANE_AGE  DEPARTING_AIRPORT  PREVIOUS_AIRPORT  PRCP  \
# 0              0.001265         19  Atlanta Municipal              NONE   0.0
# 1              0.001265         22  Atlanta Municipal              NONE   0.0
# 2              0.001265         24  Atlanta Municipal              NONE   0.0
# 3              0.000911         20  Atlanta Municipal              NONE   0.0
# 4              0.000492         21  Atlanta Municipal              NONE   0.0
#
#   SNOW SNWD  TMAX  AWND
# 0  0.0  0.0  72.0  4.47
# 1  0.0  0.0  72.0  4.47
# 2  0.0  0.0  72.0  4.47
# 3  0.0  0.0  72.0  4.47
# 4  0.0  0.0  72.0  4.47
#
# [5 rows x 23 columns]

# %% [markdown]
# # Graph

# %% [markdown]
# ## DAY_OF_WEEK

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.DAY_OF_WEEK)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='DAY_OF_WEEK'>

# %% [markdown]
# ## DISTANCE_GROUP

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.DISTANCE_GROUP, split=True)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='DISTANCE_GROUP'>

# %%
data["DISTANCE_GROUP"].value_counts()
# Out:
# 3     32847
# 2     25883
# 4     19861
# 1     16585
# 5      9621
# 7      5746
# 6      5115
# 8      2143
# 9      1259
# 11      400
# 10      271
# Name: DISTANCE_GROUP, dtype: int64

# %%
DISTANCE_GROUP = pd.crosstab(index=data["DISTANCE_GROUP"], 
                           columns=data["DEP_DEL15"])
DISTANCE_GROUP
# Out:
# DEP_DEL15           0     1
# DISTANCE_GROUP
# 1               13966  2619
# 2               22088  3795
# 3               28229  4618
# 4               16860  3001
# 5                8077  1544
# 6                4182   933
# 7                4842   904
# 8                1813   330
# 9                1063   196
# 10                231    40
# 11                321    79

# %% [markdown]
# ## DEP_BLOCK

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.DEP_BLOCK, split=True)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='DEP_BLOCK'>

# %% [markdown]
# ## SEGMENT_NUMBER

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.SEGMENT_NUMBER)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='SEGMENT_NUMBER'>

# %% [markdown]
# ## CONCURRENT_FLIGHTS

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.CONCURRENT_FLIGHTS)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='CONCURRENT_FLIGHTS'>

# %%
CF = pd.crosstab(index=data["CONCURRENT_FLIGHTS"], columns=data["DEP_DEL15"])
CFmin = CF[CF[1]/(CF[1]+CF[0])>0.2]
CFmin
# Out:
# DEP_DEL15              0    1
# CONCURRENT_FLIGHTS
# 1                      3    2
# 13                    40   11
# 14                    39   16
# 33                    50   16
# 37                    25   12
# 42                   126   42
# 47                    67   27
# 49                    39   10
# 53                    29   24
# 59                   167   69
# 60                   142   38
# 61                   339   88
# 62                   235   74
# 63                    87   39
# 64                    46   18
# 66                    71   61
# 67                    52   15
# 76                    58   18
# 77                    60   17
# 81                   191   52
# 82                    49   33
# 85                    42   43
# 94                     7   87
# 103                  108   98
# 110                   83   25
# 121                   75   46
# 122                  358  113
# 123                  675  171
# 138                  184   89
# 145                  521  180
# 149                  582  155
# 150                  562  186
# 152                  114   37
# 153                  840  226
# 164                 1072  367
# 166                 1039  269
# 198                  151   45
# 212                  657  175
# 218                  774  297
# 219                  331  105
# 222                  169   52
# 224                  334  113
# 225                  505  167
# 226                  504  174
# 236                  511  187
# 239                  373  105
# 243                  387   98
# 245                  766  208

# %%
CFmin.describe()
# Out:
# DEP_DEL15            0           1
# count        48.000000   48.000000
# mean        284.145833   93.750000
# std         288.095654   84.839147
# min           3.000000    2.000000
# 25%          56.500000   26.500000
# 50%         159.000000   65.000000
# 75%         504.250000  158.000000
# max        1072.000000  367.000000

# %% [markdown]
# ## NUMBER_OF_SEATS

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.NUMBER_OF_SEATS)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='NUMBER_OF_SEATS'>

# %%
NOS = pd.crosstab(index=data["NUMBER_OF_SEATS"], columns=data["DEP_DEL15"])
NOSmin = NOS[NOS[1]/(NOS[1]+NOS[0])>0.2]
NOSmin
# Out:
# DEP_DEL15           0    1
# NUMBER_OF_SEATS
# 65                 23    7
# 66               2602  731
# 79               1239  338
# 146                28   11
# 170                 1    1
# 176               369  131
# 181              2369  598
# 188                61   31
# 198                28    8
# 200                48   15
# 208                19    7
# 209                10   11
# 211                 3    2
# 216               600  161
# 219                21    9
# 267                 3    1
# 273               127   51
# 285                94   28
# 304                 0    1

# %%
NOSmin.describe()
# Out:
# DEP_DEL15            0           1
# count        19.000000   19.000000
# mean        402.368421  112.736842
# std         794.835707  212.507736
# min           0.000000    1.000000
# 25%          14.500000    7.000000
# 50%          28.000000   11.000000
# 75%         248.000000   91.000000
# max        2602.000000  731.000000

# %% [markdown]
# ## CARRIER_NAME

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.CARRIER_NAME)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='CARRIER_NAME'>

# %% [markdown]
# ## AIRPORT_FLIGHTS_MONTH

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AIRPORT_FLIGHTS_MONTH)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AIRPORT_FLIGHTS_MONTH'>

# %% [markdown]
# ## AIRLINE_FLIGHTS_MONTH

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AIRLINE_FLIGHTS_MONTH)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AIRLINE_FLIGHTS_MONTH'>

# %% [markdown]
# ## AIRLINE_AIRPORT_FLIGHTS_MONTH

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AIRLINE_AIRPORT_FLIGHTS_MONTH)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AIRLINE_AIRPORT_FLIGHTS_MONTH'>

# %%
AAFM = pd.crosstab(index=data["AIRLINE_AIRPORT_FLIGHTS_MONTH"], columns=data["DEP_DEL15"])
AAFMmin = AAFM[(AAFM[1]+AAFM[0])<100]
AAFMmin
# Out:
# DEP_DEL15                       0   1
# AIRLINE_AIRPORT_FLIGHTS_MONTH
# 1                               0   1
# 10                              9   1
# 36                             28   8
# 74                             58  15
# 85                             70  15
# 86                             62  24
# 91                             81  10
# 93                             69  24
# 96                             78  18

# %%
AAFM.describe()
# Out:
# DEP_DEL15             0            1
# count         63.000000    63.000000
# mean        1613.841270   286.650794
# std         2827.146397   485.010913
# min            0.000000     1.000000
# 25%          140.500000    25.000000
# 50%          485.000000    60.000000
# 75%         1530.500000   310.000000
# max        17351.000000  2505.000000

# %% [markdown]
# ## AVG_MONTHLY_PASS_AIRPORT

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AVG_MONTHLY_PASS_AIRPORT)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AVG_MONTHLY_PASS_AIRPORT'>

# %% [markdown]
# ## AVG_MONTHLY_PASS_AIRLINE

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AVG_MONTHLY_PASS_AIRLINE)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AVG_MONTHLY_PASS_AIRLINE'>

# %% [markdown]
# ## FLT_ATTENDANTS_PER_PASS

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.FLT_ATTENDANTS_PER_PASS)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='FLT_ATTENDANTS_PER_PASS'>

# %% [markdown]
# ## GROUND_SERV_PER_PASS

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.GROUND_SERV_PER_PASS)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='GROUND_SERV_PER_PASS'>

# %% [markdown]
# ## PLANE_AGE

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.PLANE_AGE)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='PLANE_AGE'>

# %% [markdown]
# ## DEPARTING_AIRPORT

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.DEPARTING_AIRPORT)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='DEPARTING_AIRPORT'>

# %% [markdown]
# ## PREVIOUS_AIRPORT

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.PREVIOUS_AIRPORT)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='PREVIOUS_AIRPORT'>

# %% [markdown]
# ## PRCP

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.PRCP)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='PRCP'>

# %% [markdown]
# ## SNOW

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.SNOW)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='SNOW'>

# %% [markdown]
# ## SNWD

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.SNWD)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='SNWD'>

# %% [markdown]
# ## TMAX

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.TMAX)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='TMAX'>

# %% [markdown]
# ## AWND

# %%
sns.violinplot(x=data.DEP_DEL15 , y=data.AWND)
# Out:
# <AxesSubplot:xlabel='DEP_DEL15', ylabel='AWND'>
