# %%
test = 'https://raw.githubusercontent.com/alyspal/Data-Mining-and-Knowledge-Management/main/Test.csv?token=AVAPFCZVH2LWRLKX2RCUGHLBTTFDG'
df1 = pd.read_csv(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f834e00b2132> in <module>()
#       1 test = 'https://raw.githubusercontent.com/alyspal/Data-Mining-and-Knowledge-Management/main/Test.csv?token=AVAPFCZVH2LWRLKX2RCUGHLBTTFDG'
# ----> 2 df1 = pd.read_csv(test)
#
# NameError: name 'pd' is not defined

# %%
train = 'https://raw.githubusercontent.com/alyspal/Data-Mining-and-Knowledge-Management/main/Train.csv?token=AVAPFC3JUPXHZSCOQQLC7ELBTTFFQ'
datatrain = pd.read_csv(train)
