# %%
install.packages("plyr")
library(plyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# # Data

# %%
vaksinasi<-  read.csv("vaksinasi.csv")

# %%
head(vaksinasi)
# Out:
#   Sex    Age         Professions        Education       Living.Area
# 1 Male   51-55 years Medical specialist Master degree   Downtown
# 2 Female 41-45 years Non medical staff  Master degree   Downtown
# 3 Male   56-60 years Medical doctor     Master degree   Downtown
# 4 Male   26-30 years Non medical staff  Bachelor degree Downtown
# 5 Female 31-35 years Medical doctor     Bachelor degree Downtown
# 6 Male   46-50 years Non medical staff  Bachelor degree Downtown
#   X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 1 No           No          No          No        No           ⋯ No
# 2 No           No          No          No        No           ⋯ No
# 3 No           No          No          No        No           ⋯ No
# 4 No           No          No          No        No           ⋯ No
# 5 No           No          No          No        No           ⋯ Yes
# 6 No           No          No          No        No           ⋯ No
# ...

# %%
data<-data.frame(vaksinasi)

# %% [markdown]
# # Gender

# %% [markdown]
# ## Male

# %%
maledata = data[data$Sex =="Male",]
dfmaledata <- data.frame(maledata)
dim(maledata)
head(maledata)
# Out:
# [1] 270  22
#    Sex  Age         Professions        Education       Living.Area X1..Swelling
# 1  Male 51-55 years Medical specialist Master degree   Downtown    No
# 3  Male 56-60 years Medical doctor     Master degree   Downtown    No
# 4  Male 26-30 years Non medical staff  Bachelor degree Downtown    No
# 6  Male 46-50 years Non medical staff  Bachelor degree Downtown    No
# 10 Male 51-55 years Nurse              Master degree   Downtown    No
# 15 Male 31-35 years Nurse              Bachelor degree Downtown    No
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 1  No          No          No        No           ⋯ No           No
# 3  No          No          No        No           ⋯ No           No
# 4  No          No          No        No           ⋯ No           No
# 6  No          No          No        No           ⋯ No           No
# 10 No          No          No        No           ⋯ No           No
# ...

# %%
maleswelling = length(which(dfmaledata$X1..Swelling == "Yes"))
maleredness = length(which(dfmaledata$X2..Redness == "Yes"))
maleitching = length(which(dfmaledata$X3..Itching == "Yes"))
malefever = length(which(dfmaledata$X4..Fever == "Yes"))
maleheadache = length(which(dfmaledata$X5..Headache == "Yes"))
malesmusclepain = length(which(dfmaledata$X6..Muscle.Pain == "Yes"))
maletiredness = length(which(dfmaledata$X7..Tiredness == "Yes"))
malecoughing = length(which(dfmaledata$X8..Coughing == "Yes"))
malediarrhea = length(which(dfmaledata$X9..Diarrhea == "Yes"))
malenausea = length(which(dfmaledata$X10..Nausea.and.vomiting == "Yes"))
malebreathless = length(which(dfmaledata$X11..Breathlessness == "Yes"))
malejointpain = length(which(dfmaledata$X12..Joint.Pain == "Yes"))
malefainted = length(which(dfmaledata$X13..Fainted == "Yes"))
maleanaphylactic = length(which(dfmaledata$X14..Anaphylactic.Reaction == "Yes"))
maletingling = length(which(dfmaledata$X15..Tingling == "Yes"))
malesln = length(which(dfmaledata$X16..Swollen.Lymph.Nodes == "Yes"))

# %%
count(dfmaledata,"X1..Swelling")
count(dfmaledata,"X2..Redness")
count(dfmaledata,"X3..Itching")
count(dfmaledata,"X4..Fever")
count(dfmaledata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           248
# 2 Yes           22
#   X2..Redness freq
# 1 No          268
# 2 Yes           2
#   X3..Itching freq
# 1 No          270
#   X4..Fever freq
# 1 No        266
# 2 Yes         4
#   X5..Headache freq
# 1 No           233
# 2 Yes           37

# %%
count(dfmaledata,"X6..Muscle.Pain")
count(dfmaledata,"X7..Tiredness")
count(dfmaledata,"X8..Coughing")
count(dfmaledata,"X9..Diarrhea")
count(dfmaledata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              187
# 2 Yes              83
#   X7..Tiredness freq
# 1 No            172
# 2 Yes            98
#   X8..Coughing freq
# 1 No           247
# 2 Yes           23
#   X9..Diarrhea freq
# 1 No           262
# 2 Yes            8
#   X10..Nausea.and.vomiting freq
# 1 No                       269
# 2 Yes                        1

# %%
count(dfmaledata,"X11..Breathlessness")
count(dfmaledata,"X12..Joint.Pain")
count(dfmaledata,"X13..Fainted")
count(dfmaledata,"X14..Anaphylactic.Reaction")
count(dfmaledata,"X15..Tingling")
count(dfmaledata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  266
# 2 Yes                   4
#   X12..Joint.Pain freq
# 1 No              265
# 2 Yes               5
#   X13..Fainted freq
# 1 No           269
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         269
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            257
# 2 Yes            13
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       270

# %% [markdown]
# ##Female

# %%
femaledata = data[data$Sex =="Female",]
dffemaledata <- data.frame(femaledata)
dim(femaledata)
head(femaledata)
# Out:
# [1] 570  22
#    Sex    Age         Professions       Education       Living.Area
# 2  Female 41-45 years Non medical staff Master degree   Downtown
# 5  Female 31-35 years Medical doctor    Bachelor degree Downtown
# 7  Female 46-50 years Medical doctor    Bachelor degree Downtown
# 8  Female 56-60 years Medical doctor    Master degree   Downtown
# 9  Female 36-40 years Non medical staff Master degree   Downtown
# 11 Female 56-60 years Nurse             Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 2  No           No          No          No        No           ⋯ No
# 5  No           No          No          No        No           ⋯ Yes
# 7  No           No          No          No        No           ⋯ No
# 8  No           No          No          No        No           ⋯ No
# 9  No           No          No          No        No           ⋯ No
# 11 No           No          No          No        Yes          ⋯ No
# ...

# %%
count(dffemaledata,"X1..Swelling")
count(dffemaledata,"X2..Redness")
count(dffemaledata,"X3..Itching")
count(dffemaledata,"X4..Fever")
count(dffemaledata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           515
# 2 Yes           55
#   X2..Redness freq
# 1 No          555
# 2 Yes          15
#   X3..Itching freq
# 1 No          570
#   X4..Fever freq
# 1 No        561
# 2 Yes         9
#   X5..Headache freq
# 1 No           421
# 2 Yes          149

# %%
count(dffemaledata,"X6..Muscle.Pain")
count(dffemaledata,"X7..Tiredness")
count(dffemaledata,"X8..Coughing")
count(dffemaledata,"X9..Diarrhea")
count(dffemaledata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              320
# 2 Yes             250
#   X7..Tiredness freq
# 1 No            367
# 2 Yes           203
#   X8..Coughing freq
# 1 No           527
# 2 Yes           43
#   X9..Diarrhea freq
# 1 No           552
# 2 Yes           18
#   X10..Nausea.and.vomiting freq
# 1 No                       558
# 2 Yes                       12

# %%
count(dffemaledata,"X11..Breathlessness")
count(dffemaledata,"X12..Joint.Pain")
count(dffemaledata,"X13..Fainted")
count(dffemaledata,"X14..Anaphylactic.Reaction")
count(dffemaledata,"X15..Tingling")
count(dffemaledata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  563
# 2 Yes                   7
#   X12..Joint.Pain freq
# 1 No              562
# 2 Yes               8
#   X13..Fainted freq
# 1 No           570
#   X14..Anaphylactic.Reaction freq
# 1 No                         568
# 2 Yes                          2
#   X15..Tingling freq
# 1 No            525
# 2 Yes            45
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       566
# 2 Yes                        4

# %% [markdown]
# ## Uji 2 Proporsi

# %%
head(dfmaledata)
dim(dfmaledata)
# Out:
#    Sex  Age         Professions        Education       Living.Area X1..Swelling
# 1  Male 51-55 years Medical specialist Master degree   Downtown    No
# 3  Male 56-60 years Medical doctor     Master degree   Downtown    No
# 4  Male 26-30 years Non medical staff  Bachelor degree Downtown    No
# 6  Male 46-50 years Non medical staff  Bachelor degree Downtown    No
# 10 Male 51-55 years Nurse              Master degree   Downtown    No
# 15 Male 31-35 years Nurse              Bachelor degree Downtown    No
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 1  No          No          No        No           ⋯ No           No
# 3  No          No          No        No           ⋯ No           No
# 4  No          No          No        No           ⋯ No           No
# 6  No          No          No        No           ⋯ No           No
# 10 No          No          No        No           ⋯ No           No
# ...

# %%
propallmale = nrow(dfmaledata)
propallfemale = nrow(dffemaledata)
propallmale
propallfemale
# Out:
# [1] 270
# [1] 570

# %%
propmale1 = length(which(dfmaledata$X1..Swelling == "Yes"))
propfemale1 = length(which(dffemaledata$X1..Swelling == "Yes"))
gender1 <- prop.test(x = c(propmale1,propfemale1),n = c(propallmale,propallfemale),alternative = c("greater"))
gender1
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale1, propfemale1) out of c(propallmale, propallfemale)
# X-squared = 0.33186, df = 1, p-value = 0.7177
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05185284  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.08148148 0.09649123

# %%
propmale2 = length(which(dfmaledata$X2..Redness == "Yes"))
propfemale2 = length(which(dffemaledata$X2..Redness == "Yes"))
gender2 <- prop.test(x = c(propmale2,propfemale2),n = c(propallmale,propallfemale),alternative = c("greater"))
gender2
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale2, propfemale2) out of c(propallmale, propallfemale)
# X-squared = 2.4187, df = 1, p-value = 0.9401
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.03561237  1.00000000
# sample estimates:
#      prop 1      prop 2
# 0.007407407 0.026315789

# %%
propmale3 = length(which(dfmaledata$X3..Itching == "Yes"))
propfemale3 = length(which(dffemaledata$X3..Itching == "Yes"))
gender3 <- prop.test(x = c(propmale3,propfemale3),n = c(propallmale,propallfemale))
gender3
# Out:
# Warning message in prop.test(x = c(propmale3, propfemale3), n = c(propallmale, propallfemale)):
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions without continuity
# 	correction
#
# data:  c(propmale3, propfemale3) out of c(propallmale, propallfemale)
# X-squared = NaN, df = 1, p-value = NA
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  0 0
# sample estimates:
# prop 1 prop 2
#      0      0

# %%
propmale4 = length(which(dfmaledata$X4..Fever == "Yes"))
propfemale4 = length(which(dffemaledata$X4..Fever == "Yes"))
gender4 <- prop.test(x = c(propmale4,propfemale4),n = c(propallmale,propallfemale))
gender4
# Out:
# Warning message in prop.test(x = c(propmale4, propfemale4), n = c(propallmale, propallfemale)):
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale4, propfemale4) out of c(propallmale, propallfemale)
# X-squared = 6.6931e-30, df = 1, p-value = 1
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.01962383  0.01767451
# sample estimates:
#     prop 1     prop 2
# 0.01481481 0.01578947

# %%
propmale5 = length(which(dfmaledata$X5..Headache == "Yes"))
propfemale5 = length(which(dffemaledata$X5..Headache == "Yes"))
gender5 <- prop.test(x = c(propmale5,propfemale5),n = c(propallmale,propallfemale),alternative = c("greater"))
gender5
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale5, propfemale5) out of c(propallmale, propallfemale)
# X-squared = 15.724, df = 1, p-value = 1
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.1729369  1.0000000
# sample estimates:
#    prop 1    prop 2
# 0.1370370 0.2614035

# %%
propmale6 = length(which(dfmaledata$X6..Muscle.Pain == "Yes"))
propfemale6 = length(which(dffemaledata$X6..Muscle.Pain == "Yes"))
gender6 <- prop.test(x = c(propmale6,propfemale6),n = c(propallmale,propallfemale),alternative = c("greater"))
gender6
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale6, propfemale6) out of c(propallmale, propallfemale)
# X-squared = 12.636, df = 1, p-value = 0.9998
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.1913829  1.0000000
# sample estimates:
#    prop 1    prop 2
# 0.3074074 0.4385965

# %%
propmale7 = length(which(dfmaledata$X7..Tiredness == "Yes"))
propfemale7 = length(which(dffemaledata$X7..Tiredness == "Yes"))
gender7 <- prop.test(x = c(propmale7,propfemale7),n = c(propallmale,propallfemale),alternative = c("greater"))
gender7
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale7, propfemale7) out of c(propallmale, propallfemale)
# X-squared = 0.013353, df = 1, p-value = 0.454
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05426193  1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.3629630 0.3561404

# %%
propmale8 = length(which(dfmaledata$X8..Coughing == "Yes"))
propfemale8 = length(which(dffemaledata$X8..Coughing == "Yes"))
gender8 <- prop.test(x = c(propmale8,propfemale8),n = c(propallmale,propallfemale),alternative = c("greater"))
gender8
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale8, propfemale8) out of c(propallmale, propallfemale)
# X-squared = 0.12462, df = 1, p-value = 0.362
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02632835  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.08518519 0.07543860

# %%
propmale9 = length(which(dfmaledata$X9..Diarrhea == "Yes"))
propfemale9 = length(which(dffemaledata$X9..Diarrhea == "Yes"))
gender9 <- prop.test(x = c(propmale9,propfemale9),n = c(propallmale,propallfemale),alternative = c("greater"))
gender9
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale9, propfemale9) out of c(propallmale, propallfemale)
# X-squared = 4.2295e-30, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02471367  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.02962963 0.03157895

# %%
propmale10 = length(which(dfmaledata$X10..Nausea.and.vomiting == "Yes"))
propfemale10 = length(which(dffemaledata$X10..Nausea.and.vomiting == "Yes"))
gender10 <- prop.test(x = c(propmale10,propfemale10),n = c(propallmale,propallfemale))
gender10
# Out:
# Warning message in prop.test(x = c(propmale10, propfemale10), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale10, propfemale10) out of c(propallmale, propallfemale)
# X-squared = 2.5701, df = 1, p-value = 0.1089
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.033912527 -0.000785329
# sample estimates:
#      prop 1      prop 2
# 0.003703704 0.021052632

# %%
propmale11 = length(which(dfmaledata$X11..Breathlessness == "Yes"))
propfemale11 = length(which(dffemaledata$X11..Breathlessness == "Yes"))
gender11 <- prop.test(x = c(propmale11,propfemale11),n = c(propallmale,propallfemale))
gender11
# Out:
# Warning message in prop.test(x = c(propmale11, propfemale11), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale11, propfemale11) out of c(propallmale, propallfemale)
# X-squared = 4.4768e-30, df = 1, p-value = 1
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.01701191  0.02208014
# sample estimates:
#     prop 1     prop 2
# 0.01481481 0.01228070

# %%
propmale12 = length(which(dfmaledata$X12..Joint.Pain == "Yes"))
propfemale12 = length(which(dffemaledata$X12..Joint.Pain == "Yes"))
gender12 <- prop.test(x = c(propmale12,propfemale12),n = c(propallmale,propallfemale))
gender12
# Out:
# Warning message in prop.test(x = c(propmale12, propfemale12), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale12, propfemale12) out of c(propallmale, propallfemale)
# X-squared = 0.03701, df = 1, p-value = 0.8474
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.01700344  0.02597030
# sample estimates:
#     prop 1     prop 2
# 0.01851852 0.01403509

# %%
propmale13 = length(which(dfmaledata$X13..Fainted == "Yes"))
propfemale13 = length(which(dffemaledata$X13..Fainted == "Yes"))
gender13 <- prop.test(x = c(propmale13,propfemale13),n = c(propallmale,propallfemale))
gender13
# Out:
# Warning message in prop.test(x = c(propmale13, propfemale13), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale13, propfemale13) out of c(propallmale, propallfemale)
# X-squared = 0.14637, df = 1, p-value = 0.702
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.006271012  0.013678419
# sample estimates:
#      prop 1      prop 2
# 0.003703704 0.000000000

# %%
propmale14 = length(which(dfmaledata$X14..Anaphylactic.Reaction == "Yes"))
propfemale14 = length(which(dffemaledata$X14..Anaphylactic.Reaction == "Yes"))
gender14 <- prop.test(x = c(propmale14,propfemale14),n = c(propallmale,propallfemale))
gender14
# Out:
# Warning message in prop.test(x = c(propmale14, propfemale14), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale14, propfemale14) out of c(propallmale, propallfemale)
# X-squared = 4.4338e-30, df = 1, p-value = 1
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.008721456  0.009111319
# sample estimates:
#      prop 1      prop 2
# 0.003703704 0.003508772

# %%
propmale15 = length(which(dfmaledata$X15..Tingling == "Yes"))
propfemale15 = length(which(dffemaledata$X15..Tingling == "Yes"))
gender15 <- prop.test(x = c(propmale15,propfemale15),n = c(propallmale,propallfemale),alternative = c("greater"))
gender15
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale15, propfemale15) out of c(propallmale, propallfemale)
# X-squared = 2.2458, df = 1, p-value = 0.933
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.06188995  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.04814815 0.07894737

# %%
propmale16 = length(which(dfmaledata$X16..Swollen.Lymph.Nodes == "Yes"))
propfemale16 = length(which(dffemaledata$X16..Swollen.Lymph.Nodes == "Yes"))
gender16 <- prop.test(x = c(propmale16,propfemale16),n = c(propallmale,propallfemale))
gender16
# Out:
# Warning message in prop.test(x = c(propmale16, propfemale16), n = c(propallmale, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propmale16, propfemale16) out of c(propallmale, propallfemale)
# X-squared = 0.71099, df = 1, p-value = 0.3991
# alternative hypothesis: two.sided
# 95 percent confidence interval:
#  -0.016599483  0.002564395
# sample estimates:
#      prop 1      prop 2
# 0.000000000 0.007017544

# %% [markdown]
# # Age

# %%
unique(data$Age)
# Out:
#  [1] "51-55 years" "41-45 years" "56-60 years" "26-30 years" "31-35 years"
#  [6] "46-50 years" "36-40 years" "20-25 years" "> 60 years"  "< 20 years"

# %% [markdown]
# ## Age < 20 years

# %%
agebelow20data = data[data$Age =="< 20 years",]
dfagebelow20data <- data.frame(agebelow20data)
dim(agebelow20data)
head(agebelow20data)
# Out:
# [1]  3 22
#     Sex    Age        Professions       Education          Living.Area
# 150 Female < 20 years Non medical staff Senior high school Outskirt
# 309 Female < 20 years Non medical staff Senior high school Downtown
# 659 Female < 20 years Non medical staff Senior high school Outskirt
#     X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 150 No           No          No          No        No           ⋯ No
# 309 Yes          No          No          No        No           ⋯ No
# 659 No           No          No          No        No           ⋯ No
#     X9..Diarrhea X10..Nausea.and.vomiting X11..Breathlessness X12..Joint.Pain
# 150 No           No                       No                  No
# 309 No           No                       No                  No
# 659 No           No                       No                  No
#     X13..Fainted X14..Anaphylactic.Reaction X15..Tingling
# 150 No           No                         No
# ...

# %%
count(dfagebelow20data,"X1..Swelling")
count(dfagebelow20data,"X2..Redness")
count(dfagebelow20data,"X3..Itching")
count(dfagebelow20data,"X4..Fever")
count(dfagebelow20data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           2
# 2 Yes          1
#   X2..Redness freq
# 1 No          3
#   X3..Itching freq
# 1 No          3
#   X4..Fever freq
# 1 No        3
#   X5..Headache freq
# 1 No           3

# %%
count(dfagebelow20data,"X6..Muscle.Pain")
count(dfagebelow20data,"X7..Tiredness")
count(dfagebelow20data,"X8..Coughing")
count(dfagebelow20data,"X9..Diarrhea")
count(dfagebelow20data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              3
#   X7..Tiredness freq
# 1 No            2
# 2 Yes           1
#   X8..Coughing freq
# 1 No           3
#   X9..Diarrhea freq
# 1 No           3
#   X10..Nausea.and.vomiting freq
# 1 No                       3

# %%
count(dfagebelow20data,"X11..Breathlessness")
count(dfagebelow20data,"X12..Joint.Pain")
count(dfagebelow20data,"X13..Fainted")
count(dfagebelow20data,"X14..Anaphylactic.Reaction")
count(dfagebelow20data,"X15..Tingling")
count(dfagebelow20data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  3
#   X12..Joint.Pain freq
# 1 No              3
#   X13..Fainted freq
# 1 No           3
#   X14..Anaphylactic.Reaction freq
# 1 No                         3
#   X15..Tingling freq
# 1 No            2
# 2 Yes           1
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       3

# %% [markdown]
# ## Age 20-25 years

# %%
age2025data = data[data$Age =="20-25 years",]
dfage2025data <-data.frame(age2025data)
dim(age2025data)
head(age2025data)
# Out:
# [1] 79 22
#     Sex    Age         Professions       Education          Living.Area
# 40  Female 20-25 years Nurse             Bachelor degree    Downtown
# 50  Female 20-25 years Nurse             Bachelor degree    Downtown
# 55  Female 20-25 years Nurse             Bachelor degree    Outskirt
# 79  Female 20-25 years Nurse             Bachelor degree    Downtown
# 87  Female 20-25 years Non medical staff Senior high school Downtown
# 130 Female 20-25 years Non medical staff Senior high school Downtown
#     X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 40  No           No          No          No        No           ⋯ No
# 50  No           No          No          No        Yes          ⋯ No
# 55  Yes          Yes         No          No        No           ⋯ No
# 79  Yes          No          No          No        No           ⋯ No
# 87  No           No          No          No        No           ⋯ No
# ...

# %%
count(dfage2025data,"X1..Swelling")
count(dfage2025data,"X2..Redness")
count(dfage2025data,"X3..Itching")
count(dfage2025data,"X4..Fever")
count(dfage2025data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           68
# 2 Yes          11
#   X2..Redness freq
# 1 No          73
# 2 Yes          6
#   X3..Itching freq
# 1 No          79
#   X4..Fever freq
# 1 No        78
# 2 Yes        1
#   X5..Headache freq
# 1 No           62
# 2 Yes          17

# %%
count(dfage2025data,"X6..Muscle.Pain")
count(dfage2025data,"X7..Tiredness")
count(dfage2025data,"X8..Coughing")
count(dfage2025data,"X9..Diarrhea")
count(dfage2025data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              43
# 2 Yes             36
#   X7..Tiredness freq
# 1 No            52
# 2 Yes           27
#   X8..Coughing freq
# 1 No           77
# 2 Yes           2
#   X9..Diarrhea freq
# 1 No           79
#   X10..Nausea.and.vomiting freq
# 1 No                       78
# 2 Yes                       1

# %%
count(dfage2025data,"X11..Breathlessness")
count(dfage2025data,"X12..Joint.Pain")
count(dfage2025data,"X13..Fainted")
count(dfage2025data,"X14..Anaphylactic.Reaction")
count(dfage2025data,"X15..Tingling")
count(dfage2025data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  79
#   X12..Joint.Pain freq
# 1 No              76
# 2 Yes              3
#   X13..Fainted freq
# 1 No           79
#   X14..Anaphylactic.Reaction freq
# 1 No                         79
#   X15..Tingling freq
# 1 No            75
# 2 Yes            4
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       79

# %% [markdown]
# ## Age 26-30 years

# %%
age2630data = data[data$Age =="26-30 years",]
dfage2630data <- data.frame(age2630data)
dim(age2630data)
head(age2630data)
# Out:
# [1] 205  22
#    Sex    Age         Professions       Education       Living.Area
# 4  Male   26-30 years Non medical staff Bachelor degree Downtown
# 25 Female 26-30 years Medical doctor    Bachelor degree Downtown
# 27 Female 26-30 years Non medical staff Bachelor degree Outskirt
# 35 Female 26-30 years Non medical staff Bachelor degree Outskirt
# 38 Female 26-30 years Non medical staff Bachelor degree Outskirt
# 46 Female 26-30 years Non medical staff Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 4  No           No          No          No        No           ⋯ No
# 25 No           No          No          No        No           ⋯ No
# 27 No           No          No          No        No           ⋯ No
# 35 Yes          No          No          No        Yes          ⋯ No
# 38 Yes          No          No          No        No           ⋯ No
# 46 Yes          No          No          No        Yes          ⋯ No
# ...

# %%
count(dfage2630data,"X1..Swelling")
count(dfage2630data,"X2..Redness")
count(dfage2630data,"X3..Itching")
count(dfage2630data,"X4..Fever")
count(dfage2630data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           178
# 2 Yes           27
#   X2..Redness freq
# 1 No          203
# 2 Yes           2
#   X3..Itching freq
# 1 No          205
#   X4..Fever freq
# 1 No        202
# 2 Yes         3
#   X5..Headache freq
# 1 No           151
# 2 Yes           54

# %%
count(dfage2630data,"X6..Muscle.Pain")
count(dfage2630data,"X7..Tiredness")
count(dfage2630data,"X8..Coughing")
count(dfage2630data,"X9..Diarrhea")
count(dfage2630data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              108
# 2 Yes              97
#   X7..Tiredness freq
# 1 No            131
# 2 Yes            74
#   X8..Coughing freq
# 1 No           192
# 2 Yes           13
#   X9..Diarrhea freq
# 1 No           200
# 2 Yes            5
#   X10..Nausea.and.vomiting freq
# 1 No                       204
# 2 Yes                        1

# %%
count(dfage2630data,"X11..Breathlessness")
count(dfage2630data,"X12..Joint.Pain")
count(dfage2630data,"X13..Fainted")
count(dfage2630data,"X14..Anaphylactic.Reaction")
count(dfage2630data,"X15..Tingling")
count(dfage2630data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  200
# 2 Yes                   5
#   X12..Joint.Pain freq
# 1 No              202
# 2 Yes               3
#   X13..Fainted freq
# 1 No           205
#   X14..Anaphylactic.Reaction freq
# 1 No                         205
#   X15..Tingling freq
# 1 No            189
# 2 Yes            16
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       204
# 2 Yes                        1

# %% [markdown]
# ## Age 31-35 years

# %%
age3135data = data[data$Age =="31-35 years",]
dfage3135data <- data.frame(age3135data)
dim(age3135data)
head(age3135data)
# Out:
# [1] 190  22
#    Sex    Age         Professions       Education          Living.Area
# 5  Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 12 Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 15 Male   31-35 years Nurse             Bachelor degree    Downtown
# 20 Male   31-35 years Non medical staff Senior high school Downtown
# 29 Male   31-35 years Nurse             Bachelor degree    Outskirt
# 33 Male   31-35 years Non medical staff Senior high school Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 5  No           No          No          No        No           ⋯ Yes
# 12 No           No          No          No        No           ⋯ No
# 15 No           No          No          No        Yes          ⋯ Yes
# 20 No           No          No          No        No           ⋯ No
# 29 Yes          No          No          No        No           ⋯ No
# ...

# %%
count(dfage3135data,"X1..Swelling")
count(dfage3135data,"X2..Redness")
count(dfage3135data,"X3..Itching")
count(dfage3135data,"X4..Fever")
count(dfage3135data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           175
# 2 Yes           15
#   X2..Redness freq
# 1 No          188
# 2 Yes           2
#   X3..Itching freq
# 1 No          190
#   X4..Fever freq
# 1 No        189
# 2 Yes         1
#   X5..Headache freq
# 1 No           145
# 2 Yes           45

# %%
count(dfage3135data,"X6..Muscle.Pain")
count(dfage3135data,"X7..Tiredness")
count(dfage3135data,"X8..Coughing")
count(dfage3135data,"X9..Diarrhea")
count(dfage3135data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              116
# 2 Yes              74
#   X7..Tiredness freq
# 1 No            119
# 2 Yes            71
#   X8..Coughing freq
# 1 No           171
# 2 Yes           19
#   X9..Diarrhea freq
# 1 No           184
# 2 Yes            6
#   X10..Nausea.and.vomiting freq
# 1 No                       187
# 2 Yes                        3

# %%
count(dfage3135data,"X11..Breathlessness")
count(dfage3135data,"X12..Joint.Pain")
count(dfage3135data,"X13..Fainted")
count(dfage3135data,"X14..Anaphylactic.Reaction")
count(dfage3135data,"X15..Tingling")
count(dfage3135data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  189
# 2 Yes                   1
#   X12..Joint.Pain freq
# 1 No              188
# 2 Yes               2
#   X13..Fainted freq
# 1 No           190
#   X14..Anaphylactic.Reaction freq
# 1 No                         190
#   X15..Tingling freq
# 1 No            183
# 2 Yes             7
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       189
# 2 Yes                        1

# %% [markdown]
# ## Age 36-40 years

# %%
age3640data = data[data$Age =="36-40 years",]
dfage3640data <- data.frame(age3640data)
dim(age3640data)
head(age3640data)
# Out:
# [1] 120  22
#    Sex    Age         Professions        Education          Living.Area
# 9  Female 36-40 years Non medical staff  Master degree      Downtown
# 21 Female 36-40 years Non medical staff  Senior high school Outskirt
# 22 Male   36-40 years Non medical staff  Master degree      Outskirt
# 26 Male   36-40 years Medical specialist Master degree      Downtown
# 30 Female 36-40 years Nurse              Bachelor degree    Downtown
# 34 Male   36-40 years Nurse              Bachelor degree    Outskirt
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 9  No           No          No          No        No           ⋯ No
# 21 No           No          No          No        No           ⋯ No
# 22 No           No          No          No        No           ⋯ No
# 26 No           No          No          No        No           ⋯ No
# 30 Yes          No          No          No        Yes          ⋯ No
# ...

# %%
count(dfage3640data,"X1..Swelling")
count(dfage3640data,"X2..Redness")
count(dfage3640data,"X3..Itching")
count(dfage3640data,"X4..Fever")
count(dfage3640data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           110
# 2 Yes           10
#   X2..Redness freq
# 1 No          116
# 2 Yes           4
#   X3..Itching freq
# 1 No          120
#   X4..Fever freq
# 1 No        120
#   X5..Headache freq
# 1 No           93
# 2 Yes          27

# %%
count(dfage3640data,"X6..Muscle.Pain")
count(dfage3640data,"X7..Tiredness")
count(dfage3640data,"X8..Coughing")
count(dfage3640data,"X9..Diarrhea")
count(dfage3640data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              71
# 2 Yes             49
#   X7..Tiredness freq
# 1 No            79
# 2 Yes           41
#   X8..Coughing freq
# 1 No           111
# 2 Yes            9
#   X9..Diarrhea freq
# 1 No           115
# 2 Yes            5
#   X10..Nausea.and.vomiting freq
# 1 No                       116
# 2 Yes                        4

# %%
count(dfage3640data,"X11..Breathlessness")
count(dfage3640data,"X12..Joint.Pain")
count(dfage3640data,"X13..Fainted")
count(dfage3640data,"X14..Anaphylactic.Reaction")
count(dfage3640data,"X15..Tingling")
count(dfage3640data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  120
#   X12..Joint.Pain freq
# 1 No              120
#   X13..Fainted freq
# 1 No           120
#   X14..Anaphylactic.Reaction freq
# 1 No                         120
#   X15..Tingling freq
# 1 No            110
# 2 Yes            10
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       119
# 2 Yes                        1

# %% [markdown]
# ## Age 41-45 years

# %%
age4145data = data[data$Age =="41-45 years",]
dfage4145data <- data.frame(age4145data)
dim(age4145data)
head(age4145data)
# Out:
# [1] 72 22
#    Sex    Age         Professions       Education       Living.Area
# 2  Female 41-45 years Non medical staff Master degree   Downtown
# 13 Female 41-45 years Nurse             Bachelor degree Downtown
# 14 Female 41-45 years Nurse             Bachelor degree Outskirt
# 24 Female 41-45 years Non medical staff Master degree   Downtown
# 28 Female 41-45 years Nurse             Master degree   Downtown
# 36 Male   41-45 years Nurse             Master degree   Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 2  No           No          No          No        No           ⋯ No
# 13 No           No          No          No        No           ⋯ No
# 14 No           No          No          No        No           ⋯ No
# 24 No           No          No          No        No           ⋯ No
# 28 No           No          No          No        No           ⋯ No
# 36 Yes          No          No          No        No           ⋯ No
# ...

# %%
count(dfage4145data,"X1..Swelling")
count(dfage4145data,"X2..Redness")
count(dfage4145data,"X3..Itching")
count(dfage4145data,"X4..Fever")
count(dfage4145data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           65
# 2 Yes           7
#   X2..Redness freq
# 1 No          72
#   X3..Itching freq
# 1 No          72
#   X4..Fever freq
# 1 No        67
# 2 Yes        5
#   X5..Headache freq
# 1 No           58
# 2 Yes          14

# %%
count(dfage4145data,"X6..Muscle.Pain")
count(dfage4145data,"X7..Tiredness")
count(dfage4145data,"X8..Coughing")
count(dfage4145data,"X9..Diarrhea")
count(dfage4145data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              44
# 2 Yes             28
#   X7..Tiredness freq
# 1 No            38
# 2 Yes           34
#   X8..Coughing freq
# 1 No           64
# 2 Yes           8
#   X9..Diarrhea freq
# 1 No           70
# 2 Yes           2
#   X10..Nausea.and.vomiting freq
# 1 No                       71
# 2 Yes                       1

# %%
count(dfage4145data,"X11..Breathlessness")
count(dfage4145data,"X12..Joint.Pain")
count(dfage4145data,"X13..Fainted")
count(dfage4145data,"X14..Anaphylactic.Reaction")
count(dfage4145data,"X15..Tingling")
count(dfage4145data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  71
# 2 Yes                  1
#   X12..Joint.Pain freq
# 1 No              68
# 2 Yes              4
#   X13..Fainted freq
# 1 No           71
# 2 Yes           1
#   X14..Anaphylactic.Reaction freq
# 1 No                         71
# 2 Yes                         1
#   X15..Tingling freq
# 1 No            62
# 2 Yes           10
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       72

# %% [markdown]
# ## Age 46-50 years

# %%
age4650data = data[data$Age =="46-50 years",]
dfage4650data <- data.frame(age4650data)
dim(age4650data)
head(age4650data)
# Out:
# [1] 70 22
#    Sex    Age         Professions       Education       Living.Area
# 6  Male   46-50 years Non medical staff Bachelor degree Downtown
# 7  Female 46-50 years Medical doctor    Bachelor degree Downtown
# 23 Male   46-50 years Non medical staff Master degree   Outskirt
# 32 Female 46-50 years Nurse             Bachelor degree Outskirt
# 37 Male   46-50 years Non medical staff Master degree   Downtown
# 42 Female 46-50 years Midwife           Bachelor degree Outskirt
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 6  No           No          No          No        No           ⋯ No
# 7  No           No          No          No        No           ⋯ No
# 23 No           No          No          No        Yes          ⋯ Yes
# 32 No           No          No          No        No           ⋯ No
# 37 No           No          No          No        No           ⋯ Yes
# 42 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfage4650data,"X1..Swelling")
count(dfage4650data,"X2..Redness")
count(dfage4650data,"X3..Itching")
count(dfage4650data,"X4..Fever")
count(dfage4650data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           69
# 2 Yes           1
#   X2..Redness freq
# 1 No          68
# 2 Yes          2
#   X3..Itching freq
# 1 No          70
#   X4..Fever freq
# 1 No        69
# 2 Yes        1
#   X5..Headache freq
# 1 No           60
# 2 Yes          10

# %%
count(dfage4650data,"X6..Muscle.Pain")
count(dfage4650data,"X7..Tiredness")
count(dfage4650data,"X8..Coughing")
count(dfage4650data,"X9..Diarrhea")
count(dfage4650data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              54
# 2 Yes             16
#   X7..Tiredness freq
# 1 No            48
# 2 Yes           22
#   X8..Coughing freq
# 1 No           62
# 2 Yes           8
#   X9..Diarrhea freq
# 1 No           67
# 2 Yes           3
#   X10..Nausea.and.vomiting freq
# 1 No                       68
# 2 Yes                       2

# %%
count(dfage4650data,"X11..Breathlessness")
count(dfage4650data,"X12..Joint.Pain")
count(dfage4650data,"X13..Fainted")
count(dfage4650data,"X14..Anaphylactic.Reaction")
count(dfage4650data,"X15..Tingling")
count(dfage4650data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  69
# 2 Yes                  1
#   X12..Joint.Pain freq
# 1 No              70
#   X13..Fainted freq
# 1 No           70
#   X14..Anaphylactic.Reaction freq
# 1 No                         68
# 2 Yes                         2
#   X15..Tingling freq
# 1 No            65
# 2 Yes            5
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       70

# %% [markdown]
# ## Age 51-55 years

# %%
age5155data = data[data$Age =="51-55 years",]
dfage5155data <- data.frame(age5155data)
dim(age5155data)
head(age5155data)
# Out:
# [1] 72 22
#    Sex    Age         Professions        Education       Living.Area
# 1  Male   51-55 years Medical specialist Master degree   Downtown
# 10 Male   51-55 years Nurse              Master degree   Downtown
# 16 Male   51-55 years Non medical staff  Master degree   Downtown
# 17 Female 51-55 years Nurse              Bachelor degree Outskirt
# 18 Male   51-55 years Non medical staff  Master degree   Downtown
# 31 Female 51-55 years Non medical staff  Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 1  No           No          No          No        No           ⋯ No
# 10 No           No          No          No        No           ⋯ No
# 16 No           No          No          No        No           ⋯ No
# 17 No           No          No          No        No           ⋯ No
# 18 No           No          No          No        No           ⋯ No
# 31 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfage5155data,"X1..Swelling")
count(dfage5155data,"X2..Redness")
count(dfage5155data,"X3..Itching")
count(dfage5155data,"X4..Fever")
count(dfage5155data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           69
# 2 Yes           3
#   X2..Redness freq
# 1 No          71
# 2 Yes          1
#   X3..Itching freq
# 1 No          72
#   X4..Fever freq
# 1 No        70
# 2 Yes        2
#   X5..Headache freq
# 1 No           57
# 2 Yes          15

# %%
count(dfage5155data,"X6..Muscle.Pain")
count(dfage5155data,"X7..Tiredness")
count(dfage5155data,"X8..Coughing")
count(dfage5155data,"X9..Diarrhea")
count(dfage5155data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              46
# 2 Yes             26
#   X7..Tiredness freq
# 1 No            49
# 2 Yes           23
#   X8..Coughing freq
# 1 No           66
# 2 Yes           6
#   X9..Diarrhea freq
# 1 No           68
# 2 Yes           4
#   X10..Nausea.and.vomiting freq
# 1 No                       71
# 2 Yes                       1

# %%
count(dfage5155data,"X11..Breathlessness")
count(dfage5155data,"X12..Joint.Pain")
count(dfage5155data,"X13..Fainted")
count(dfage5155data,"X14..Anaphylactic.Reaction")
count(dfage5155data,"X15..Tingling")
count(dfage5155data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  70
# 2 Yes                  2
#   X12..Joint.Pain freq
# 1 No              71
# 2 Yes              1
#   X13..Fainted freq
# 1 No           72
#   X14..Anaphylactic.Reaction freq
# 1 No                         72
#   X15..Tingling freq
# 1 No            68
# 2 Yes            4
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       71
# 2 Yes                       1

# %% [markdown]
# ## Age 56-60 years

# %%
age5660data = data[data$Age =="56-60 years",]
dfage5660data <- data.frame(age5660data)
dim(age5660data)
head(age5660data)
# Out:
# [1] 26 22
#    Sex    Age         Professions        Education       Living.Area
# 3  Male   56-60 years Medical doctor     Master degree   Downtown
# 8  Female 56-60 years Medical doctor     Master degree   Downtown
# 11 Female 56-60 years Nurse              Bachelor degree Downtown
# 19 Female 56-60 years Nurse              Master degree   Outskirt
# 77 Female 56-60 years Medical specialist Master degree   Downtown
# 90 Female 56-60 years Non medical staff  Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 3  No           No          No          No        No           ⋯ No
# 8  No           No          No          No        No           ⋯ No
# 11 No           No          No          No        Yes          ⋯ No
# 19 No           No          No          No        No           ⋯ No
# 77 No           No          No          No        Yes          ⋯ No
# 90 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfage5660data,"X1..Swelling")
count(dfage5660data,"X2..Redness")
count(dfage5660data,"X3..Itching")
count(dfage5660data,"X4..Fever")
count(dfage5660data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           24
# 2 Yes           2
#   X2..Redness freq
# 1 No          26
#   X3..Itching freq
# 1 No          26
#   X4..Fever freq
# 1 No        26
#   X5..Headache freq
# 1 No           22
# 2 Yes           4

# %%
count(dfage5660data,"X6..Muscle.Pain")
count(dfage5660data,"X7..Tiredness")
count(dfage5660data,"X8..Coughing")
count(dfage5660data,"X9..Diarrhea")
count(dfage5660data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              20
# 2 Yes              6
#   X7..Tiredness freq
# 1 No            18
# 2 Yes            8
#   X8..Coughing freq
# 1 No           25
# 2 Yes           1
#   X9..Diarrhea freq
# 1 No           25
# 2 Yes           1
#   X10..Nausea.and.vomiting freq
# 1 No                       26

# %%
count(dfage5660data,"X11..Breathlessness")
count(dfage5660data,"X12..Joint.Pain")
count(dfage5660data,"X13..Fainted")
count(dfage5660data,"X14..Anaphylactic.Reaction")
count(dfage5660data,"X15..Tingling")
count(dfage5660data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  25
# 2 Yes                  1
#   X12..Joint.Pain freq
# 1 No              26
#   X13..Fainted freq
# 1 No           26
#   X14..Anaphylactic.Reaction freq
# 1 No                         26
#   X15..Tingling freq
# 1 No            25
# 2 Yes            1
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       26

# %% [markdown]
# ## Age > 60 years

# %%
ageabove60data = data[data$Age =="> 60 years",]
dfageabove60data <- data.frame(ageabove60data)
dim(ageabove60data)
head(ageabove60data)
# Out:
# [1]  3 22
#     Sex    Age        Professions        Education       Living.Area
# 58  Female > 60 years Medical doctor     Bachelor degree Downtown
# 767 Female > 60 years Medical doctor     Master degree   Downtown
# 830 Male   > 60 years Medical specialist Master degree   Downtown
#     X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 58  No           No          No          No        No           ⋯ No
# 767 No           No          No          No        No           ⋯ No
# 830 No           No          No          No        No           ⋯ No
#     X9..Diarrhea X10..Nausea.and.vomiting X11..Breathlessness X12..Joint.Pain
# 58  No           No                       No                  No
# 767 No           No                       No                  No
# 830 No           No                       No                  No
#     X13..Fainted X14..Anaphylactic.Reaction X15..Tingling
# 58  No           No                         No
# ...

# %%
count(dfageabove60data,"X1..Swelling")
count(dfageabove60data,"X2..Redness")
count(dfageabove60data,"X3..Itching")
count(dfageabove60data,"X4..Fever")
count(dfageabove60data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           3
#   X2..Redness freq
# 1 No          3
#   X3..Itching freq
# 1 No          3
#   X4..Fever freq
# 1 No        3
#   X5..Headache freq
# 1 No           3

# %%
count(dfageabove60data,"X6..Muscle.Pain")
count(dfageabove60data,"X7..Tiredness")
count(dfageabove60data,"X8..Coughing")
count(dfageabove60data,"X9..Diarrhea")
count(dfageabove60data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              2
# 2 Yes             1
#   X7..Tiredness freq
# 1 No            3
#   X8..Coughing freq
# 1 No           3
#   X9..Diarrhea freq
# 1 No           3
#   X10..Nausea.and.vomiting freq
# 1 No                       3

# %%
count(dfageabove60data,"X11..Breathlessness")
count(dfageabove60data,"X12..Joint.Pain")
count(dfageabove60data,"X13..Fainted")
count(dfageabove60data,"X14..Anaphylactic.Reaction")
count(dfageabove60data,"X15..Tingling")
count(dfageabove60data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  3
#   X12..Joint.Pain freq
# 1 No              3
#   X13..Fainted freq
# 1 No           3
#   X14..Anaphylactic.Reaction freq
# 1 No                         3
#   X15..Tingling freq
# 1 No            3
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       3

# %% [markdown]
# ## Uji Proporsi

# %%
agecategory1 <- data[ which( data$Age =="< 20 years" |
data$Age == "20-25 years" | data$Age == "26-30 years" | 
data$Age == "31-35 years" | data$Age == "36-40 years"), ]
dfagecategory1 <- data.frame(agecategory1)
agecategory2 <- data[ which( data$Age =="41-45 years" |
data$Age == "46-50 years" | data$Age == "51-55 years" | 
data$Age == "56-60 years" | data$Age == "> 60 years"), ]
dfagecategory2 <- data.frame(agecategory2)
head(agecategory1)
head(agecategory2)
# Out:
#    Sex    Age         Professions       Education          Living.Area
# 4  Male   26-30 years Non medical staff Bachelor degree    Downtown
# 5  Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 9  Female 36-40 years Non medical staff Master degree      Downtown
# 12 Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 15 Male   31-35 years Nurse             Bachelor degree    Downtown
# 20 Male   31-35 years Non medical staff Senior high school Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 4  No           No          No          No        No           ⋯ No
# 5  No           No          No          No        No           ⋯ Yes
# 9  No           No          No          No        No           ⋯ No
# 12 No           No          No          No        No           ⋯ No
# 15 No           No          No          No        Yes          ⋯ Yes
# 20 No           No          No          No        No           ⋯ No
# ...

# %%
propallagecategory1 = nrow(dfagecategory1)
propallagecategory2 = nrow(dfagecategory2)
propallagecategory1
propallagecategory2
# Out:
# [1] 597
# [1] 243

# %%
count(dfagecategory1,"X1..Swelling")
count(dfagecategory1,"X2..Redness")
count(dfagecategory1,"X3..Itching")
count(dfagecategory1,"X4..Fever")
count(dfagecategory1,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           533
# 2 Yes           64
#   X2..Redness freq
# 1 No          583
# 2 Yes          14
#   X3..Itching freq
# 1 No          597
#   X4..Fever freq
# 1 No        592
# 2 Yes         5
#   X5..Headache freq
# 1 No           454
# 2 Yes          143

# %%
count(dfagecategory1,"X6..Muscle.Pain")
count(dfagecategory1,"X7..Tiredness")
count(dfagecategory1,"X8..Coughing")
count(dfagecategory1,"X9..Diarrhea")
count(dfagecategory1,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              341
# 2 Yes             256
#   X7..Tiredness freq
# 1 No            383
# 2 Yes           214
#   X8..Coughing freq
# 1 No           554
# 2 Yes           43
#   X9..Diarrhea freq
# 1 No           581
# 2 Yes           16
#   X10..Nausea.and.vomiting freq
# 1 No                       588
# 2 Yes                        9

# %%
count(dfagecategory1,"X11..Breathlessness")
count(dfagecategory1,"X12..Joint.Pain")
count(dfagecategory1,"X13..Fainted")
count(dfagecategory1,"X14..Anaphylactic.Reaction")
count(dfagecategory1,"X15..Tingling")
count(dfagecategory1,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  591
# 2 Yes                   6
#   X12..Joint.Pain freq
# 1 No              589
# 2 Yes               8
#   X13..Fainted freq
# 1 No           597
#   X14..Anaphylactic.Reaction freq
# 1 No                         597
#   X15..Tingling freq
# 1 No            559
# 2 Yes            38
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       594
# 2 Yes                        3

# %%
count(dfagecategory2,"X1..Swelling")
count(dfagecategory2,"X2..Redness")
count(dfagecategory2,"X3..Itching")
count(dfagecategory2,"X4..Fever")
count(dfagecategory2,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           230
# 2 Yes           13
#   X2..Redness freq
# 1 No          240
# 2 Yes           3
#   X3..Itching freq
# 1 No          243
#   X4..Fever freq
# 1 No        235
# 2 Yes         8
#   X5..Headache freq
# 1 No           200
# 2 Yes           43

# %%
count(dfagecategory2,"X6..Muscle.Pain")
count(dfagecategory2,"X7..Tiredness")
count(dfagecategory2,"X8..Coughing")
count(dfagecategory2,"X9..Diarrhea")
count(dfagecategory2,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              166
# 2 Yes              77
#   X7..Tiredness freq
# 1 No            156
# 2 Yes            87
#   X8..Coughing freq
# 1 No           220
# 2 Yes           23
#   X9..Diarrhea freq
# 1 No           233
# 2 Yes           10
#   X10..Nausea.and.vomiting freq
# 1 No                       239
# 2 Yes                        4

# %%
count(dfagecategory2,"X11..Breathlessness")
count(dfagecategory2,"X12..Joint.Pain")
count(dfagecategory2,"X13..Fainted")
count(dfagecategory2,"X14..Anaphylactic.Reaction")
count(dfagecategory2,"X15..Tingling")
count(dfagecategory2,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  238
# 2 Yes                   5
#   X12..Joint.Pain freq
# 1 No              238
# 2 Yes               5
#   X13..Fainted freq
# 1 No           242
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         240
# 2 Yes                          3
#   X15..Tingling freq
# 1 No            223
# 2 Yes            20
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       242
# 2 Yes                        1

# %%
agecategory1 <- data[ which( data$Age =="< 20 years" |
data$Age == "20-25 years" | data$Age == "26-30 years" | 
data$Age == "31-35 years" | data$Age == "36-40 years"), ]
dfagecategory1 <- data.frame(agecategory1)
agecategory2 <- data[ which( data$Age =="41-45 years" |
data$Age == "46-50 years" | data$Age == "51-55 years" | 
data$Age == "56-60 years" | data$Age == "> 60 years"), ]
dfagecategory2 <- data.frame(agecategory2)
head(agecategory1)
head(agecategory2)
# Out:
#    Sex    Age         Professions       Education          Living.Area
# 4  Male   26-30 years Non medical staff Bachelor degree    Downtown
# 5  Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 9  Female 36-40 years Non medical staff Master degree      Downtown
# 12 Female 31-35 years Medical doctor    Bachelor degree    Downtown
# 15 Male   31-35 years Nurse             Bachelor degree    Downtown
# 20 Male   31-35 years Non medical staff Senior high school Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 4  No           No          No          No        No           ⋯ No
# 5  No           No          No          No        No           ⋯ Yes
# 9  No           No          No          No        No           ⋯ No
# 12 No           No          No          No        No           ⋯ No
# 15 No           No          No          No        Yes          ⋯ Yes
# 20 No           No          No          No        No           ⋯ No
# ...

# %%
propallagecategory1 = nrow(dfagecategory1)
propallagecategory2 = nrow(dfagecategory2)
propallagecategory1
propallagecategory2
# Out:
# [1] 597
# [1] 243

# %%
count(dfagecategory1,"X1..Swelling")
count(dfagecategory1,"X2..Redness")
count(dfagecategory1,"X3..Itching")
count(dfagecategory1,"X4..Fever")
count(dfagecategory1,"X5..Headache")
# Out:
# Error in count(dfagecategory1, "X1..Swelling"): could not find function "count"
# Traceback:

# %%
count(dfagecategory1,"X6..Muscle.Pain")
count(dfagecategory1,"X7..Tiredness")
count(dfagecategory1,"X8..Coughing")
count(dfagecategory1,"X9..Diarrhea")
count(dfagecategory1,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              187
# 2 Yes              83
#   X7..Tiredness freq
# 1 No            172
# 2 Yes            98
#   X8..Coughing freq
# 1 No           247
# 2 Yes           23
#   X9..Diarrhea freq
# 1 No           262
# 2 Yes            8
#   X10..Nausea.and.vomiting freq
# 1 No                       269
# 2 Yes                        1

# %%
count(dfagecategory1,"X11..Breathlessness")
count(dfagecategory1,"X12..Joint.Pain")
count(dfagecategory1,"X13..Fainted")
count(dfagecategory1,"X14..Anaphylactic.Reaction")
count(dfagecategory1,"X15..Tingling")
count(dfagecategory1,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  266
# 2 Yes                   4
#   X12..Joint.Pain freq
# 1 No              265
# 2 Yes               5
#   X13..Fainted freq
# 1 No           269
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         269
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            257
# 2 Yes            13
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       270

# %%
count(dfagecategory1,"X1..Swelling")
count(dfagecategory1,"X2..Redness")
count(dfagecategory1,"X3..Itching")
count(dfagecategory1,"X4..Fever")
count(dfagecategory1,"X5..Headache")

# %%
count(dfagecategory1,"X6..Muscle.Pain")
count(dfagecategory1,"X7..Tiredness")
count(dfagecategory1,"X8..Coughing")
count(dfagecategory1,"X9..Diarrhea")
count(dfagecategory1,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              187
# 2 Yes              83
#   X7..Tiredness freq
# 1 No            172
# 2 Yes            98
#   X8..Coughing freq
# 1 No           247
# 2 Yes           23
#   X9..Diarrhea freq
# 1 No           262
# 2 Yes            8
#   X10..Nausea.and.vomiting freq
# 1 No                       269
# 2 Yes                        1

# %%
count(dfagecategory1,"X11..Breathlessness")
count(dfagecategory1,"X12..Joint.Pain")
count(dfagecategory1,"X13..Fainted")
count(dfagecategory1,"X14..Anaphylactic.Reaction")
count(dfagecategory1,"X15..Tingling")
count(dfagecategory1,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  266
# 2 Yes                   4
#   X12..Joint.Pain freq
# 1 No              265
# 2 Yes               5
#   X13..Fainted freq
# 1 No           269
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         269
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            257
# 2 Yes            13
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       270

# %%
propagecategory1_1 = length(which(dfagecategory1$X1..Swelling == "Yes"))
propagecategory2_1 = length(which(dfagecategory2$X1..Swelling == "Yes"))
prop.test(x = c(propagecategory1_1,propagecategory2_1),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_1, propagecategory2_1) out of c(propallagecategory1, propallagecategory2)
# X-squared = 5.3547, df = 1, p-value = 0.01033
# alternative hypothesis: greater
# 95 percent confidence interval:
#  0.01922597 1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.10720268 0.05349794

# %%
propagecategory1_2 = length(which(dfagecategory1$X2..Redness == "Yes"))
propagecategory2_2 = length(which(dfagecategory2$X2..Redness == "Yes"))
prop.test(x = c(propagecategory1_2,propagecategory2_2),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_2, propagecategory2_2), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_2, propagecategory2_2) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.58705, df = 1, p-value = 0.2218
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.007267381  1.000000000
# sample estimates:
#     prop 1     prop 2
# 0.02345059 0.01234568

# %%
propagecategory1_4 = length(which(dfagecategory1$X4..Fever == "Yes"))
propagecategory2_4 = length(which(dfagecategory2$X4..Fever == "Yes"))
prop.test(x = c(propagecategory1_4,propagecategory2_4),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_4, propagecategory2_4), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_4, propagecategory2_4) out of c(propallagecategory1, propallagecategory2)
# X-squared = 5.3136, df = 1, p-value = 0.9894
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.04724373  1.00000000
# sample estimates:
#      prop 1      prop 2
# 0.008375209 0.032921811

# %%
propagecategory1_5 = length(which(dfagecategory1$X5..Headache == "Yes"))
propagecategory2_5 = length(which(dfagecategory2$X5..Headache == "Yes"))
prop.test(x = c(propagecategory1_5,propagecategory2_5),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_5, propagecategory2_5) out of c(propallagecategory1, propallagecategory2)
# X-squared = 3.5682, df = 1, p-value = 0.02945
# alternative hypothesis: greater
# 95 percent confidence interval:
#  0.01021319 1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.2395310 0.1769547

# %%
propagecategory1_6 = length(which(dfagecategory1$X6..Muscle.Pain == "Yes"))
propagecategory2_6 = length(which(dfagecategory2$X6..Muscle.Pain == "Yes"))
prop.test(x = c(propagecategory1_6,propagecategory2_6),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_6, propagecategory2_6) out of c(propallagecategory1, propallagecategory2)
# X-squared = 8.5823, df = 1, p-value = 0.001697
# alternative hypothesis: greater
# 95 percent confidence interval:
#  0.04971269 1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.4288107 0.3168724

# %%
propagecategory1_7 = length(which(dfagecategory1$X7..Tiredness == "Yes"))
propagecategory2_7 = length(which(dfagecategory2$X7..Tiredness == "Yes"))
prop.test(x = c(propagecategory1_7,propagecategory2_7),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_7, propagecategory2_7) out of c(propallagecategory1, propallagecategory2)
# X-squared = 2.9184e-30, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.06001031  1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.3584590 0.3580247

# %%
propagecategory1_8 = length(which(dfagecategory1$X8..Coughing == "Yes"))
propagecategory2_8 = length(which(dfagecategory2$X8..Coughing == "Yes"))
prop.test(x = c(propagecategory1_8,propagecategory2_8),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_8, propagecategory2_8) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.92844, df = 1, p-value = 0.8324
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.0609726  1.0000000
# sample estimates:
#     prop 1     prop 2
# 0.07202680 0.09465021

# %%
propagecategory1_9 = length(which(dfagecategory1$X9..Diarrhea == "Yes"))
propagecategory2_9 = length(which(dfagecategory2$X9..Diarrhea == "Yes"))
prop.test(x = c(propagecategory1_9,propagecategory2_9),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_9, propagecategory2_9) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.75572, df = 1, p-value = 0.8077
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.04085888  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.02680067 0.04115226

# %%
propagecategory1_10 = length(which(dfagecategory1$X10..Nausea.and.vomiting == "Yes"))
propagecategory2_10 = length(which(dfagecategory2$X10..Nausea.and.vomiting == "Yes"))
prop.test(x = c(propagecategory1_10,propagecategory2_10),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_10, propagecategory2_10), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_10, propagecategory2_10) out of c(propallagecategory1, propallagecategory2)
# X-squared = 9.6149e-30, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.01850471  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01507538 0.01646091

# %%
propagecategory1_11 = length(which(dfagecategory1$X11..Breathlessness == "Yes"))
propagecategory2_11 = length(which(dfagecategory2$X11..Breathlessness == "Yes"))
prop.test(x = c(propagecategory1_11,propagecategory2_11),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_11, propagecategory2_11), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_11, propagecategory2_11) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.77812, df = 1, p-value = 0.8111
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.0298365  1.0000000
# sample estimates:
#     prop 1     prop 2
# 0.01005025 0.02057613

# %%
propagecategory1_12 = length(which(dfagecategory1$X12..Joint.Pain == "Yes"))
propagecategory2_12 = length(which(dfagecategory2$X12..Joint.Pain == "Yes"))
prop.test(x = c(propagecategory1_12,propagecategory2_12),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_12, propagecategory2_12), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_12, propagecategory2_12) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.2077, df = 1, p-value = 0.6757
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02693196  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01340034 0.02057613

# %%
propagecategory1_13 = length(which(dfagecategory1$X13..Fainted == "Yes"))
propagecategory2_13 = length(which(dfagecategory2$X13..Fainted == "Yes"))
prop.test(x = c(propagecategory1_13,propagecategory2_13),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_13, propagecategory2_13), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_13, propagecategory2_13) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.21621, df = 1, p-value = 0.679
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.01376536  1.00000000
# sample estimates:
#      prop 1      prop 2
# 0.000000000 0.004115226

# %%
propagecategory1_14 = length(which(dfagecategory1$X14..Anaphylactic.Reaction == "Yes"))
propagecategory2_14 = length(which(dfagecategory2$X14..Anaphylactic.Reaction == "Yes"))
prop.test(x = c(propagecategory1_14,propagecategory2_14),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_14, propagecategory2_14), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_14, propagecategory2_14) out of c(propallagecategory1, propallagecategory2)
# X-squared = 4.3344, df = 1, p-value = 0.9813
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02689237  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.00000000 0.01234568

# %%
propagecategory1_15 = length(which(dfagecategory1$X15..Tingling == "Yes"))
propagecategory2_15 = length(which(dfagecategory2$X15..Tingling == "Yes"))
prop.test(x = c(propagecategory1_15,propagecategory2_15),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_15, propagecategory2_15) out of c(propallagecategory1, propallagecategory2)
# X-squared = 0.66714, df = 1, p-value = 0.793
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05488052  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.06365159 0.08230453

# %%
propagecategory1_16 = length(which(dfagecategory1$X16..Swollen.Lymph.Nodes == "Yes"))
propagecategory2_16 = length(which(dfagecategory2$X16..Swollen.Lymph.Nodes == "Yes"))
prop.test(x = c(propagecategory1_16,propagecategory2_16),n = c(propallagecategory1,propallagecategory2),alternative = c("greater"))
# Out:
# Warning message in prop.test(x = c(propagecategory1_16, propagecategory2_16), n = c(propallagecategory1, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propagecategory1_16, propagecategory2_16) out of c(propallagecategory1, propallagecategory2)
# X-squared = 9.9834e-31, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.008263715  1.000000000
# sample estimates:
#      prop 1      prop 2
# 0.005025126 0.004115226

# %% [markdown]
# # Professions

# %%
unique(data$Professions)
# Out:
# [1] "Medical specialist" "Non medical staff"  "Medical doctor"
# [4] "Nurse"              "Midwife"

# %% [markdown]
# ## Medical Doctor

# %%
meddocdata = data[data$Professions =="Medical doctor",]
dfmeddocdata <- data.frame(meddocdata)
dim(meddocdata)
head(meddocdata)
# Out:
# [1] 115  22
#    Sex    Age Professions    Education       Living.Area X1..Swelling
# 3  Male   10  Medical doctor Master degree   Downtown    0
# 5  Female 4   Medical doctor Bachelor degree Downtown    0
# 7  Female 7   Medical doctor Bachelor degree Downtown    0
# 8  Female 10  Medical doctor Master degree   Downtown    0
# 12 Female 4   Medical doctor Bachelor degree Downtown    0
# 25 Female 3   Medical doctor Bachelor degree Downtown    0
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 3  No          No          No        No           ⋯ No           No
# 5  No          No          No        No           ⋯ Yes          No
# 7  No          No          No        No           ⋯ No           No
# 8  No          No          No        No           ⋯ No           No
# 12 No          No          No        No           ⋯ No           No
# 25 No          No          No        No           ⋯ No           No
# ...

# %%
count(dfmeddocdata,"X1..Swelling")
count(dfmeddocdata,"X2..Redness")
count(dfmeddocdata,"X3..Itching")
count(dfmeddocdata,"X4..Fever")
count(dfmeddocdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 0            114
# 2 1              1
#   X2..Redness freq
# 1 No          115
#   X3..Itching freq
# 1 No          115
#   X4..Fever freq
# 1 No        115
#   X5..Headache freq
# 1 No           96
# 2 Yes          19

# %%
count(dfmeddocdata,"X6..Muscle.Pain")
count(dfmeddocdata,"X7..Tiredness")
count(dfmeddocdata,"X8..Coughing")
count(dfmeddocdata,"X9..Diarrhea")
count(dfmeddocdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              73
# 2 Yes             42
#   X7..Tiredness freq
# 1 No            78
# 2 Yes           37
#   X8..Coughing freq
# 1 No           110
# 2 Yes            5
#   X9..Diarrhea freq
# 1 No           112
# 2 Yes            3
#   X10..Nausea.and.vomiting freq
# 1 No                       114
# 2 Yes                        1

# %%
count(dfmeddocdata,"X11..Breathlessness")
count(dfmeddocdata,"X12..Joint.Pain")
count(dfmeddocdata,"X13..Fainted")
count(dfmeddocdata,"X14..Anaphylactic.Reaction")
count(dfmeddocdata,"X15..Tingling")
count(dfmeddocdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  115
#   X12..Joint.Pain freq
# 1 No              114
# 2 Yes               1
#   X13..Fainted freq
# 1 No           115
#   X14..Anaphylactic.Reaction freq
# 1 No                         114
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            114
# 2 Yes             1
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       115

# %% [markdown]
# ## Non medical staff

# %%
nonmedstaffdata = data[data$Professions =="Non medical staff",]
dfnonmedstaffdata <- data.frame(nonmedstaffdata)
dim(nonmedstaffdata)
head(nonmedstaffdata)
# Out:
# [1] 284  22
#    Sex    Age Professions       Education       Living.Area X1..Swelling
# 2  Female 6   Non medical staff Master degree   Downtown    0
# 4  Male   3   Non medical staff Bachelor degree Downtown    0
# 6  Male   7   Non medical staff Bachelor degree Downtown    0
# 9  Female 5   Non medical staff Master degree   Downtown    0
# 16 Male   8   Non medical staff Master degree   Downtown    0
# 18 Male   8   Non medical staff Master degree   Downtown    0
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 2  No          No          No        No           ⋯ No           No
# 4  No          No          No        No           ⋯ No           No
# 6  No          No          No        No           ⋯ No           No
# 9  No          No          No        No           ⋯ No           No
# 16 No          No          No        No           ⋯ No           No
# 18 No          No          No        No           ⋯ No           No
# ...

# %%
count(dfnonmedstaffdata,"X1..Swelling")
count(dfnonmedstaffdata,"X2..Redness")
count(dfnonmedstaffdata,"X3..Itching")
count(dfnonmedstaffdata,"X4..Fever")
count(dfnonmedstaffdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 0            255
# 2 1             29
#   X2..Redness freq
# 1 No          280
# 2 Yes           4
#   X3..Itching freq
# 1 No          284
#   X4..Fever freq
# 1 No        281
# 2 Yes         3
#   X5..Headache freq
# 1 No           231
# 2 Yes           53

# %%
count(dfnonmedstaffdata,"X6..Muscle.Pain")
count(dfnonmedstaffdata,"X7..Tiredness")
count(dfnonmedstaffdata,"X8..Coughing")
count(dfnonmedstaffdata,"X9..Diarrhea")
count(dfnonmedstaffdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              184
# 2 Yes             100
#   X7..Tiredness freq
# 1 No            184
# 2 Yes           100
#   X8..Coughing freq
# 1 No           265
# 2 Yes           19
#   X9..Diarrhea freq
# 1 No           278
# 2 Yes            6
#   X10..Nausea.and.vomiting freq
# 1 No                       282
# 2 Yes                        2

# %%
count(dfnonmedstaffdata,"X11..Breathlessness")
count(dfnonmedstaffdata,"X12..Joint.Pain")
count(dfnonmedstaffdata,"X13..Fainted")
count(dfnonmedstaffdata,"X14..Anaphylactic.Reaction")
count(dfnonmedstaffdata,"X15..Tingling")
count(dfnonmedstaffdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  279
# 2 Yes                   5
#   X12..Joint.Pain freq
# 1 No              278
# 2 Yes               6
#   X13..Fainted freq
# 1 No           283
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         283
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            263
# 2 Yes            21
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       282
# 2 Yes                        2

# %% [markdown]
# ## Medical Specialist

# %%
medspecdata = data[data$Professions =="Medical specialist",]
dfmedspecdata <- data.frame(medspecdata)
dim(medspecdata)
head(medspecdata)
# Out:
# [1] 49 22
#    Sex    Age Professions        Education     Living.Area X1..Swelling
# 1  Male   8   Medical specialist Master degree Downtown    0
# 26 Male   5   Medical specialist Master degree Downtown    0
# 72 Male   8   Medical specialist Master degree Downtown    0
# 77 Female 10  Medical specialist Master degree Downtown    0
# 85 Male   5   Medical specialist Master degree Outskirt    0
# 94 Male   8   Medical specialist Master degree Downtown    0
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 1  No          No          No        No           ⋯ No           No
# 26 No          No          No        No           ⋯ No           No
# 72 No          No          Yes       Yes          ⋯ No           Yes
# 77 No          No          No        Yes          ⋯ No           No
# 85 No          No          No        No           ⋯ No           No
# 94 No          No          No        No           ⋯ No           No
# ...

# %%
count(dfmedspecdata,"X1..Swelling")
count(dfmedspecdata,"X2..Redness")
count(dfmedspecdata,"X3..Itching")
count(dfmedspecdata,"X4..Fever")
count(dfmedspecdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 0            48
# 2 1             1
#   X2..Redness freq
# 1 No          48
# 2 Yes          1
#   X3..Itching freq
# 1 No          49
#   X4..Fever freq
# 1 No        46
# 2 Yes        3
#   X5..Headache freq
# 1 No           43
# 2 Yes           6

# %%
count(dfmedspecdata,"X6..Muscle.Pain")
count(dfmedspecdata,"X7..Tiredness")
count(dfmedspecdata,"X8..Coughing")
count(dfmedspecdata,"X9..Diarrhea")
count(dfmedspecdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              28
# 2 Yes             21
#   X7..Tiredness freq
# 1 No            38
# 2 Yes           11
#   X8..Coughing freq
# 1 No           49
#   X9..Diarrhea freq
# 1 No           47
# 2 Yes           2
#   X10..Nausea.and.vomiting freq
# 1 No                       49

# %%
count(dfmedspecdata,"X11..Breathlessness")
count(dfmedspecdata,"X12..Joint.Pain")
count(dfmedspecdata,"X13..Fainted")
count(dfmedspecdata,"X14..Anaphylactic.Reaction")
count(dfmedspecdata,"X15..Tingling")
count(dfmedspecdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  49
#   X12..Joint.Pain freq
# 1 No              49
#   X13..Fainted freq
# 1 No           49
#   X14..Anaphylactic.Reaction freq
# 1 No                         49
#   X15..Tingling freq
# 1 No            48
# 2 Yes            1
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       49

# %% [markdown]
# ## Nurse

# %%
nursedata = data[data$Professions =="Nurse",]
dfnursedata <- data.frame(nursedata)
dim(nursedata)
head(nursedata)
# Out:
# [1] 363  22
#    Sex    Age Professions Education       Living.Area X1..Swelling X2..Redness
# 10 Male   8   Nurse       Master degree   Downtown    0            No
# 11 Female 10  Nurse       Bachelor degree Downtown    0            No
# 13 Female 6   Nurse       Bachelor degree Downtown    0            No
# 14 Female 6   Nurse       Bachelor degree Outskirt    0            No
# 15 Male   4   Nurse       Bachelor degree Downtown    0            No
# 17 Female 8   Nurse       Bachelor degree Outskirt    0            No
#    X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 10 No          No        No           ⋯ No           No
# 11 No          No        Yes          ⋯ No           No
# 13 No          No        No           ⋯ No           No
# 14 No          No        No           ⋯ No           No
# 15 No          No        Yes          ⋯ Yes          No
# 17 No          No        No           ⋯ No           No
# ...

# %%
count(dfnursedata,"X1..Swelling")
count(dfnursedata,"X2..Redness")
count(dfnursedata,"X3..Itching")
count(dfnursedata,"X4..Fever")
count(dfnursedata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 0            319
# 2 1             44
#   X2..Redness freq
# 1 No          351
# 2 Yes          12
#   X3..Itching freq
# 1 No          363
#   X4..Fever freq
# 1 No        356
# 2 Yes         7
#   X5..Headache freq
# 1 No           263
# 2 Yes          100

# %%
count(dfnursedata,"X6..Muscle.Pain")
count(dfnursedata,"X7..Tiredness")
count(dfnursedata,"X8..Coughing")
count(dfnursedata,"X9..Diarrhea")
count(dfnursedata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              202
# 2 Yes             161
#   X7..Tiredness freq
# 1 No            222
# 2 Yes           141
#   X8..Coughing freq
# 1 No           327
# 2 Yes           36
#   X9..Diarrhea freq
# 1 No           349
# 2 Yes           14
#   X10..Nausea.and.vomiting freq
# 1 No                       354
# 2 Yes                        9

# %%
count(dfnursedata,"X11..Breathlessness")
count(dfnursedata,"X12..Joint.Pain")
count(dfnursedata,"X13..Fainted")
count(dfnursedata,"X14..Anaphylactic.Reaction")
count(dfnursedata,"X15..Tingling")
count(dfnursedata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  357
# 2 Yes                   6
#   X12..Joint.Pain freq
# 1 No              357
# 2 Yes               6
#   X13..Fainted freq
# 1 No           363
#   X14..Anaphylactic.Reaction freq
# 1 No                         362
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            331
# 2 Yes            32
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       361
# 2 Yes                        2

# %% [markdown]
# ## Midwife

# %%
midwifedata = data[data$Professions =="Midwife",]
dfmidwifedata <- data.frame(midwifedata)
dim(midwifedata)
head(midwifedata)
# Out:
# [1] 29 22
#    Sex    Age Professions Education       Living.Area X1..Swelling X2..Redness
# 42 Female 7   Midwife     Bachelor degree Outskirt    0            No
# 59 Female 4   Midwife     Bachelor degree Outskirt    0            No
# 60 Female 4   Midwife     Bachelor degree Downtown    0            No
# 63 Female 7   Midwife     Bachelor degree Outskirt    0            No
# 65 Female 4   Midwife     Bachelor degree Downtown    0            No
# 66 Female 3   Midwife     Bachelor degree Outskirt    0            No
#    X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 42 No          No        No           ⋯ No           No
# 59 No          No        No           ⋯ No           No
# 60 No          No        Yes          ⋯ Yes          No
# 63 No          No        No           ⋯ No           No
# 65 No          No        No           ⋯ Yes          No
# 66 No          No        No           ⋯ No           No
# ...

# %%
count(dfmidwifedata,"X1..Swelling")
count(dfmidwifedata,"X2..Redness")
count(dfmidwifedata,"X3..Itching")
count(dfmidwifedata,"X4..Fever")
count(dfmidwifedata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 0            27
# 2 1             2
#   X2..Redness freq
# 1 No          29
#   X3..Itching freq
# 1 No          29
#   X4..Fever freq
# 1 No        29
#   X5..Headache freq
# 1 No           21
# 2 Yes           8

# %%
count(dfmidwifedata,"X6..Muscle.Pain")
count(dfmidwifedata,"X7..Tiredness")
count(dfmidwifedata,"X8..Coughing")
count(dfmidwifedata,"X9..Diarrhea")
count(dfmidwifedata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              20
# 2 Yes              9
#   X7..Tiredness freq
# 1 No            17
# 2 Yes           12
#   X8..Coughing freq
# 1 No           23
# 2 Yes           6
#   X9..Diarrhea freq
# 1 No           28
# 2 Yes           1
#   X10..Nausea.and.vomiting freq
# 1 No                       28
# 2 Yes                       1

# %%
count(dfmidwifedata,"X11..Breathlessness")
count(dfmidwifedata,"X12..Joint.Pain")
count(dfmidwifedata,"X13..Fainted")
count(dfmidwifedata,"X14..Anaphylactic.Reaction")
count(dfmidwifedata,"X15..Tingling")
count(dfmidwifedata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  29
#   X12..Joint.Pain freq
# 1 No              29
#   X13..Fainted freq
# 1 No           29
#   X14..Anaphylactic.Reaction freq
# 1 No                         29
#   X15..Tingling freq
# 1 No            26
# 2 Yes            3
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       29

# %% [markdown]
# # Education

# %%
unique(data$Education)
# Out:
# [1] "Master degree"      "Bachelor degree"    "Senior high school"
# [4] "Junior high school"

# %% [markdown]
# ## Master Degree

# %%
mstdegdata = data[data$Education =="Master degree",]
dfmstdegdata <- data.frame(mstdegdata)
dim(mstdegdata)
head(mstdegdata)
# Out:
# [1] 99 22
#    Sex    Age         Professions        Education     Living.Area X1..Swelling
# 1  Male   51-55 years Medical specialist Master degree Downtown    No
# 2  Female 41-45 years Non medical staff  Master degree Downtown    No
# 3  Male   56-60 years Medical doctor     Master degree Downtown    No
# 8  Female 56-60 years Medical doctor     Master degree Downtown    No
# 9  Female 36-40 years Non medical staff  Master degree Downtown    No
# 10 Male   51-55 years Nurse              Master degree Downtown    No
#    X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing X9..Diarrhea
# 1  No          No          No        No           ⋯ No           No
# 2  No          No          No        No           ⋯ No           No
# 3  No          No          No        No           ⋯ No           No
# 8  No          No          No        No           ⋯ No           No
# 9  No          No          No        No           ⋯ No           No
# ...

# %%
count(dfmstdegdata,"X1..Swelling")
count(dfmstdegdata,"X2..Redness")
count(dfmstdegdata,"X3..Itching")
count(dfmstdegdata,"X4..Fever")
count(dfmstdegdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           98
# 2 Yes           1
#   X2..Redness freq
# 1 No          97
# 2 Yes          2
#   X3..Itching freq
# 1 No          99
#   X4..Fever freq
# 1 No        95
# 2 Yes        4
#   X5..Headache freq
# 1 No           81
# 2 Yes          18

# %%
count(dfmstdegdata,"X6..Muscle.Pain")
count(dfmstdegdata,"X7..Tiredness")
count(dfmstdegdata,"X8..Coughing")
count(dfmstdegdata,"X9..Diarrhea")
count(dfmstdegdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              60
# 2 Yes             39
#   X7..Tiredness freq
# 1 No            63
# 2 Yes           36
#   X8..Coughing freq
# 1 No           90
# 2 Yes           9
#   X9..Diarrhea freq
# 1 No           94
# 2 Yes           5
#   X10..Nausea.and.vomiting freq
# 1 No                       99

# %%
count(dfmstdegdata,"X11..Breathlessness")
count(dfmstdegdata,"X12..Joint.Pain")
count(dfmstdegdata,"X13..Fainted")
count(dfmstdegdata,"X14..Anaphylactic.Reaction")
count(dfmstdegdata,"X15..Tingling")
count(dfmstdegdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  99
#   X12..Joint.Pain freq
# 1 No              99
#   X13..Fainted freq
# 1 No           99
#   X14..Anaphylactic.Reaction freq
# 1 No                         99
#   X15..Tingling freq
# 1 No            95
# 2 Yes            4
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       98
# 2 Yes                       1

# %% [markdown]
# ## Bachelor Degree

# %%
bchdegdata = data[data$Education =="Bachelor degree",]
dfbchdegdata <- data.frame(bchdegdata)
dim(bchdegdata)
head(bchdegdata)
# Out:
# [1] 632  22
#    Sex    Age         Professions       Education       Living.Area
# 4  Male   26-30 years Non medical staff Bachelor degree Downtown
# 5  Female 31-35 years Medical doctor    Bachelor degree Downtown
# 6  Male   46-50 years Non medical staff Bachelor degree Downtown
# 7  Female 46-50 years Medical doctor    Bachelor degree Downtown
# 11 Female 56-60 years Nurse             Bachelor degree Downtown
# 12 Female 31-35 years Medical doctor    Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 4  No           No          No          No        No           ⋯ No
# 5  No           No          No          No        No           ⋯ Yes
# 6  No           No          No          No        No           ⋯ No
# 7  No           No          No          No        No           ⋯ No
# 11 No           No          No          No        Yes          ⋯ No
# 12 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfbchdegdata,"X1..Swelling")
count(dfbchdegdata,"X2..Redness")
count(dfbchdegdata,"X3..Itching")
count(dfbchdegdata,"X4..Fever")
count(dfbchdegdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           564
# 2 Yes           68
#   X2..Redness freq
# 1 No          617
# 2 Yes          15
#   X3..Itching freq
# 1 No          632
#   X4..Fever freq
# 1 No        623
# 2 Yes         9
#   X5..Headache freq
# 1 No           481
# 2 Yes          151

# %%
count(dfbchdegdata,"X6..Muscle.Pain")
count(dfbchdegdata,"X7..Tiredness")
count(dfbchdegdata,"X8..Coughing")
count(dfbchdegdata,"X9..Diarrhea")
count(dfbchdegdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              373
# 2 Yes             259
#   X7..Tiredness freq
# 1 No            398
# 2 Yes           234
#   X8..Coughing freq
# 1 No           582
# 2 Yes           50
#   X9..Diarrhea freq
# 1 No           612
# 2 Yes           20
#   X10..Nausea.and.vomiting freq
# 1 No                       620
# 2 Yes                       12

# %%
count(dfbchdegdata,"X11..Breathlessness")
count(dfbchdegdata,"X12..Joint.Pain")
count(dfbchdegdata,"X13..Fainted")
count(dfbchdegdata,"X14..Anaphylactic.Reaction")
count(dfbchdegdata,"X15..Tingling")
count(dfbchdegdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  623
# 2 Yes                   9
#   X12..Joint.Pain freq
# 1 No              623
# 2 Yes               9
#   X13..Fainted freq
# 1 No           632
#   X14..Anaphylactic.Reaction freq
# 1 No                         630
# 2 Yes                          2
#   X15..Tingling freq
# 1 No            586
# 2 Yes            46
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       630
# 2 Yes                        2

# %% [markdown]
# ## Senior High School

# %%
shsdata = data[data$Education =="Senior high school",]
dfshsdata <- data.frame(shsdata)
dim(shsdata)
head(shsdata)
# Out:
# [1] 107  22
#    Sex    Age         Professions       Education          Living.Area
# 20 Male   31-35 years Non medical staff Senior high school Downtown
# 21 Female 36-40 years Non medical staff Senior high school Outskirt
# 33 Male   31-35 years Non medical staff Senior high school Downtown
# 47 Male   31-35 years Non medical staff Senior high school Outskirt
# 48 Female 31-35 years Non medical staff Senior high school Downtown
# 57 Female 41-45 years Non medical staff Senior high school Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 20 No           No          No          No        No           ⋯ No
# 21 No           No          No          No        No           ⋯ No
# 33 No           No          No          No        No           ⋯ No
# 47 No           No          No          No        No           ⋯ Yes
# 48 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfshsdata,"X1..Swelling")
count(dfshsdata,"X2..Redness")
count(dfshsdata,"X3..Itching")
count(dfshsdata,"X4..Fever")
count(dfshsdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           99
# 2 Yes           8
#   X2..Redness freq
# 1 No          107
#   X3..Itching freq
# 1 No          107
#   X4..Fever freq
# 1 No        107
#   X5..Headache freq
# 1 No           90
# 2 Yes          17

# %%
count(dfshsdata,"X6..Muscle.Pain")
count(dfshsdata,"X7..Tiredness")
count(dfshsdata,"X8..Coughing")
count(dfshsdata,"X9..Diarrhea")
count(dfshsdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              74
# 2 Yes             33
#   X7..Tiredness freq
# 1 No            76
# 2 Yes           31
#   X8..Coughing freq
# 1 No           100
# 2 Yes            7
#   X9..Diarrhea freq
# 1 No           106
# 2 Yes            1
#   X10..Nausea.and.vomiting freq
# 1 No                       106
# 2 Yes                        1

# %%
count(dfshsdata,"X11..Breathlessness")
count(dfshsdata,"X12..Joint.Pain")
count(dfshsdata,"X13..Fainted")
count(dfshsdata,"X14..Anaphylactic.Reaction")
count(dfshsdata,"X15..Tingling")
count(dfshsdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  105
# 2 Yes                   2
#   X12..Joint.Pain freq
# 1 No              103
# 2 Yes               4
#   X13..Fainted freq
# 1 No           106
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         106
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            99
# 2 Yes            8
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       106
# 2 Yes                        1

# %% [markdown]
# ## Junior High School

# %%
jhsdata = data[data$Education =="Junior high school",]
dfjhsdata <- data.frame(jhsdata)
dim(jhsdata)
head(jhsdata)
# Out:
# [1]  2 22
#     Sex    Age         Professions       Education          Living.Area
# 124 Male   26-30 years Non medical staff Junior high school Downtown
# 541 Female 41-45 years Non medical staff Junior high school Downtown
#     X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 124 No           No          No          No        No           ⋯ No
# 541 No           No          No          No        No           ⋯ No
#     X9..Diarrhea X10..Nausea.and.vomiting X11..Breathlessness X12..Joint.Pain
# 124 No           No                       No                  No
# 541 No           No                       No                  No
#     X13..Fainted X14..Anaphylactic.Reaction X15..Tingling
# 124 No           No                         No
# 541 No           No                         No
#     X16..Swollen.Lymph.Nodes Symptoms.time
# 124 No                       < 24 hours
# 541 No                       None

# %%
count(dfjhsdata,"X1..Swelling")
count(dfjhsdata,"X2..Redness")
count(dfjhsdata,"X3..Itching")
count(dfjhsdata,"X4..Fever")
count(dfjhsdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           2
#   X2..Redness freq
# 1 No          2
#   X3..Itching freq
# 1 No          2
#   X4..Fever freq
# 1 No        2
#   X5..Headache freq
# 1 No           2

# %%
count(dfjhsdata,"X6..Muscle.Pain")
count(dfjhsdata,"X7..Tiredness")
count(dfjhsdata,"X8..Coughing")
count(dfjhsdata,"X9..Diarrhea")
count(dfjhsdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 Yes             2
#   X7..Tiredness freq
# 1 No            2
#   X8..Coughing freq
# 1 No           2
#   X9..Diarrhea freq
# 1 No           2
#   X10..Nausea.and.vomiting freq
# 1 No                       2

# %%
count(dfjhsdata,"X11..Breathlessness")
count(dfjhsdata,"X12..Joint.Pain")
count(dfjhsdata,"X13..Fainted")
count(dfjhsdata,"X14..Anaphylactic.Reaction")
count(dfjhsdata,"X15..Tingling")
count(dfjhsdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  2
#   X12..Joint.Pain freq
# 1 No              2
#   X13..Fainted freq
# 1 No           2
#   X14..Anaphylactic.Reaction freq
# 1 No                         2
#   X15..Tingling freq
# 1 No            2
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       2

# %% [markdown]
# # Living Area

# %%
unique(data$Living.Area)
# Out:
# [1] "Downtown" "Outskirt"

# %% [markdown]
# ## Downtown

# %%
downtowndata = data[data$Living.Area =="Downtown",]
dfdowntowndata <- data.frame(downtowndata)
dim(downtowndata)
head(downtowndata)
# Out:
# [1] 594  22
#   Sex    Age         Professions        Education       Living.Area
# 1 Male   51-55 years Medical specialist Master degree   Downtown
# 2 Female 41-45 years Non medical staff  Master degree   Downtown
# 3 Male   56-60 years Medical doctor     Master degree   Downtown
# 4 Male   26-30 years Non medical staff  Bachelor degree Downtown
# 5 Female 31-35 years Medical doctor     Bachelor degree Downtown
# 6 Male   46-50 years Non medical staff  Bachelor degree Downtown
#   X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 1 No           No          No          No        No           ⋯ No
# 2 No           No          No          No        No           ⋯ No
# 3 No           No          No          No        No           ⋯ No
# 4 No           No          No          No        No           ⋯ No
# 5 No           No          No          No        No           ⋯ Yes
# 6 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfdowntowndata,"X1..Swelling")
count(dfdowntowndata,"X2..Redness")
count(dfdowntowndata,"X3..Itching")
count(dfdowntowndata,"X4..Fever")
count(dfdowntowndata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           549
# 2 Yes           45
#   X2..Redness freq
# 1 No          584
# 2 Yes          10
#   X3..Itching freq
# 1 No          594
#   X4..Fever freq
# 1 No        584
# 2 Yes        10
#   X5..Headache freq
# 1 No           465
# 2 Yes          129

# %%
count(dfdowntowndata,"X6..Muscle.Pain")
count(dfdowntowndata,"X7..Tiredness")
count(dfdowntowndata,"X8..Coughing")
count(dfdowntowndata,"X9..Diarrhea")
count(dfdowntowndata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              357
# 2 Yes             237
#   X7..Tiredness freq
# 1 No            380
# 2 Yes           214
#   X8..Coughing freq
# 1 No           550
# 2 Yes           44
#   X9..Diarrhea freq
# 1 No           577
# 2 Yes           17
#   X10..Nausea.and.vomiting freq
# 1 No                       586
# 2 Yes                        8

# %%
count(dfdowntowndata,"X11..Breathlessness")
count(dfdowntowndata,"X12..Joint.Pain")
count(dfdowntowndata,"X13..Fainted")
count(dfdowntowndata,"X14..Anaphylactic.Reaction")
count(dfdowntowndata,"X15..Tingling")
count(dfdowntowndata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  588
# 2 Yes                   6
#   X12..Joint.Pain freq
# 1 No              586
# 2 Yes               8
#   X13..Fainted freq
# 1 No           594
#   X14..Anaphylactic.Reaction freq
# 1 No                         593
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            553
# 2 Yes            41
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       591
# 2 Yes                        3

# %% [markdown]
# ## Outskirt

# %%
outskirtdata = data[data$Living.Area =="Outskirt",]
dfoutskirtdata <- data.frame(outskirtdata)
dim(outskirtdata)
head(outskirtdata)
# Out:
# [1] 246  22
#    Sex    Age         Professions       Education          Living.Area
# 14 Female 41-45 years Nurse             Bachelor degree    Outskirt
# 17 Female 51-55 years Nurse             Bachelor degree    Outskirt
# 19 Female 56-60 years Nurse             Master degree      Outskirt
# 21 Female 36-40 years Non medical staff Senior high school Outskirt
# 22 Male   36-40 years Non medical staff Master degree      Outskirt
# 23 Male   46-50 years Non medical staff Master degree      Outskirt
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 14 No           No          No          No        No           ⋯ No
# 17 No           No          No          No        No           ⋯ No
# 19 No           No          No          No        No           ⋯ No
# 21 No           No          No          No        No           ⋯ No
# 22 No           No          No          No        No           ⋯ No
# ...

# %%
count(dfoutskirtdata,"X1..Swelling")
count(dfoutskirtdata,"X2..Redness")
count(dfoutskirtdata,"X3..Itching")
count(dfoutskirtdata,"X4..Fever")
count(dfoutskirtdata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           214
# 2 Yes           32
#   X2..Redness freq
# 1 No          239
# 2 Yes           7
#   X3..Itching freq
# 1 No          246
#   X4..Fever freq
# 1 No        243
# 2 Yes         3
#   X5..Headache freq
# 1 No           189
# 2 Yes           57

# %%
count(dfoutskirtdata,"X6..Muscle.Pain")
count(dfoutskirtdata,"X7..Tiredness")
count(dfoutskirtdata,"X8..Coughing")
count(dfoutskirtdata,"X9..Diarrhea")
count(dfoutskirtdata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              150
# 2 Yes              96
#   X7..Tiredness freq
# 1 No            159
# 2 Yes            87
#   X8..Coughing freq
# 1 No           224
# 2 Yes           22
#   X9..Diarrhea freq
# 1 No           237
# 2 Yes            9
#   X10..Nausea.and.vomiting freq
# 1 No                       241
# 2 Yes                        5

# %%
count(dfoutskirtdata,"X11..Breathlessness")
count(dfoutskirtdata,"X12..Joint.Pain")
count(dfoutskirtdata,"X13..Fainted")
count(dfoutskirtdata,"X14..Anaphylactic.Reaction")
count(dfoutskirtdata,"X15..Tingling")
count(dfoutskirtdata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  241
# 2 Yes                   5
#   X12..Joint.Pain freq
# 1 No              241
# 2 Yes               5
#   X13..Fainted freq
# 1 No           245
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         244
# 2 Yes                          2
#   X15..Tingling freq
# 1 No            229
# 2 Yes            17
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       245
# 2 Yes                        1

# %% [markdown]
# ## Uji 2 Proporsi

# %%
head(dfdowntowndata)
dim(dfoutskirtdata)
# Out:
#   Sex    Age         Professions        Education       Living.Area
# 1 Male   51-55 years Medical specialist Master degree   Downtown
# 2 Female 41-45 years Non medical staff  Master degree   Downtown
# 3 Male   56-60 years Medical doctor     Master degree   Downtown
# 4 Male   26-30 years Non medical staff  Bachelor degree Downtown
# 5 Female 31-35 years Medical doctor     Bachelor degree Downtown
# 6 Male   46-50 years Non medical staff  Bachelor degree Downtown
#   X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 1 No           No          No          No        No           ⋯ No
# 2 No           No          No          No        No           ⋯ No
# 3 No           No          No          No        No           ⋯ No
# 4 No           No          No          No        No           ⋯ No
# 5 No           No          No          No        No           ⋯ Yes
# 6 No           No          No          No        No           ⋯ No
# ...

# %%
propalldowntown = nrow(dfdowntowndata)
propalloutskirt = nrow(dfoutskirtdata)
propalldowntown
propalloutskirt
# Out:
# [1] 594
# [1] 246

# %%
propdowntown1 = length(which(dfdowntowndata$X1..Swelling == "Yes"))
propoutskirt1 = length(which(dfoutskirtdata$X1..Swelling == "Yes"))
livingarea1 <- prop.test(x = c(propdowntown1,propoutskirt1),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea1
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown1, propoutskirt1) out of c(propalldowntown, propalloutskirt)
# X-squared = 5.5303, df = 1, p-value = 0.9907
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.09673874  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.07575758 0.13008130

# %%
propdowntown2 = length(which(dfdowntowndata$X2..Redness == "Yes"))
propoutskirt2 = length(which(dfoutskirtdata$X2..Redness == "Yes"))
livingarea2 <- prop.test(x = c(propdowntown2,propoutskirt2),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea2
# Out:
# Warning message in prop.test(x = c(propdowntown2, propoutskirt2), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown2, propoutskirt2) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.67107, df = 1, p-value = 0.7937
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.03397374  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01683502 0.02845528

# %%
propdowntown4 = length(which(dfdowntowndata$X4..Fever == "Yes"))
propoutskirt4 = length(which(dfoutskirtdata$X4..Fever == "Yes"))
livingarea4 <- prop.test(x = c(propdowntown4,propoutskirt4),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea4
# Out:
# Warning message in prop.test(x = c(propdowntown4, propoutskirt4), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown4, propoutskirt4) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.035592, df = 1, p-value = 0.4252
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.01265232  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01683502 0.01219512

# %%
propdowntown5 = length(which(dfdowntowndata$X5..Headache == "Yes"))
propoutskirt5 = length(which(dfoutskirtdata$X5..Headache == "Yes"))
livingarea5 <- prop.test(x = c(propdowntown5,propoutskirt5),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea5
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown5, propoutskirt5) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.13722, df = 1, p-value = 0.6445
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.06968061  1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.2171717 0.2317073

# %%
propdowntown6 = length(which(dfdowntowndata$X6..Muscle.Pain == "Yes"))
propoutskirt6 = length(which(dfoutskirtdata$X6..Muscle.Pain == "Yes"))
livingarea6 <- prop.test(x = c(propdowntown6,propoutskirt6),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea6
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown6, propoutskirt6) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.025066, df = 1, p-value = 0.4371
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05503207  1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.3989899 0.3902439

# %%
propdowntown7 = length(which(dfdowntowndata$X7..Tiredness == "Yes"))
propoutskirt7 = length(which(dfoutskirtdata$X7..Tiredness == "Yes"))
livingarea7 <- prop.test(x = c(propdowntown7,propoutskirt7),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea7
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown7, propoutskirt7) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.010563, df = 1, p-value = 0.4591
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05596075  1.00000000
# sample estimates:
#    prop 1    prop 2
# 0.3602694 0.3536585

# %%
propdowntown8 = length(which(dfdowntowndata$X8..Coughing == "Yes"))
propoutskirt8 = length(which(dfoutskirtdata$X8..Coughing == "Yes"))
livingarea8 <- prop.test(x = c(propdowntown8,propoutskirt8),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea8
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown8, propoutskirt8) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.37439, df = 1, p-value = 0.7297
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.05298755  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.07407407 0.08943089

# %%
propdowntown9 = length(which(dfdowntowndata$X9..Diarrhea == "Yes"))
propoutskirt9 = length(which(dfoutskirtdata$X9..Diarrhea == "Yes"))
livingarea9 <- prop.test(x = c(propdowntown9,propoutskirt9),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea9
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown9, propoutskirt9) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.15035, df = 1, p-value = 0.6509
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.03351775  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.02861953 0.03658537

# %%
propdowntown10 = length(which(dfdowntowndata$X10..Nausea.and.vomiting == "Yes"))
propoutskirt10 = length(which(dfoutskirtdata$X10..Nausea.and.vomiting == "Yes"))
livingarea10 <- prop.test(x = c(propdowntown10,propoutskirt10),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea10
# Out:
# Warning message in prop.test(x = c(propdowntown10, propoutskirt10), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown10, propoutskirt10) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.18112, df = 1, p-value = 0.6648
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02645013  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01346801 0.02032520

# %%
propdowntown11 = length(which(dfdowntowndata$X11..Breathlessness == "Yes"))
propoutskirt11 = length(which(dfoutskirtdata$X11..Breathlessness == "Yes"))
livingarea11 <- prop.test(x = c(propdowntown11,propoutskirt11),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea11
# Out:
# Warning message in prop.test(x = c(propdowntown11, propoutskirt11), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown11, propoutskirt11) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.72714, df = 1, p-value = 0.8031
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02936313  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01010101 0.02032520

# %%
propdowntown12 = length(which(dfdowntowndata$X12..Joint.Pain == "Yes"))
propoutskirt12 = length(which(dfoutskirtdata$X12..Joint.Pain == "Yes"))
livingarea12 <- prop.test(x = c(propdowntown12,propoutskirt12),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea12
# Out:
# Warning message in prop.test(x = c(propdowntown12, propoutskirt12), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown12, propoutskirt12) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.18112, df = 1, p-value = 0.6648
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.02645013  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.01346801 0.02032520

# %%
propdowntown13 = length(which(dfdowntowndata$X13..Fainted == "Yes"))
propoutskirt13 = length(which(dfoutskirtdata$X13..Fainted == "Yes"))
livingarea13 <- prop.test(x = c(propdowntown13,propoutskirt13),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea13
# Out:
# Warning message in prop.test(x = c(propdowntown13, propoutskirt13), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown13, propoutskirt13) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.20744, df = 1, p-value = 0.6756
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.0136121  1.0000000
# sample estimates:
#      prop 1      prop 2
# 0.000000000 0.004065041

# %%
propdowntown14 = length(which(dfdowntowndata$X14..Anaphylactic.Reaction == "Yes"))
propoutskirt14 = length(which(dfoutskirtdata$X14..Anaphylactic.Reaction == "Yes"))
livingarea14 <- prop.test(x = c(propdowntown14,propoutskirt14),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea14
# Out:
# Warning message in prop.test(x = c(propdowntown14, propoutskirt14), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown14, propoutskirt14) out of c(propalldowntown, propalloutskirt)
# X-squared = 0.62381, df = 1, p-value = 0.7852
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.01913635  1.00000000
# sample estimates:
#      prop 1      prop 2
# 0.001683502 0.008130081

# %%
propdowntown15 = length(which(dfdowntowndata$X15..Tingling == "Yes"))
propoutskirt15 = length(which(dfoutskirtdata$X15..Tingling == "Yes"))
livingarea15 <- prop.test(x = c(propdowntown15,propoutskirt15),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea15
# Out:
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown15, propoutskirt15) out of c(propalldowntown, propalloutskirt)
# X-squared = 3.4447e-30, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.03179017  1.00000000
# sample estimates:
#     prop 1     prop 2
# 0.06902357 0.06910569

# %%
propdowntown16 = length(which(dfdowntowndata$X16..Swollen.Lymph.Nodes == "Yes"))
propoutskirt16 = length(which(dfoutskirtdata$X16..Swollen.Lymph.Nodes == "Yes"))
livingarea16 <- prop.test(x = c(propdowntown16,propoutskirt16),
n = c(propalldowntown,propalloutskirt),alternative = c("greater"))
livingarea16
# Out:
# Warning message in prop.test(x = c(propdowntown16, propoutskirt16), n = c(propalldowntown, :
# “Chi-squared approximation may be incorrect”
# 	2-sample test for equality of proportions with continuity correction
#
# data:  c(propdowntown16, propoutskirt16) out of c(propalldowntown, propalloutskirt)
# X-squared = 2.5846e-31, df = 1, p-value = 0.5
# alternative hypothesis: greater
# 95 percent confidence interval:
#  -0.0082106  1.0000000
# sample estimates:
#      prop 1      prop 2
# 0.005050505 0.004065041

# %% [markdown]
# # Symptoms Time

# %%
unique(data$Symptoms.time)
# Out:
# [1] "None"        "< 24 hours"  "24-72 hours" "> 72 hours"

# %% [markdown]
# ## None

# %%
timenonedata = data[data$Symptoms.time =="None",]
dftimenonedata <- data.frame(timenonedata)
dim(timenonedata)
head(timenonedata)
# Out:
# [1] 374  22
#    Sex    Age         Professions        Education       Living.Area
# 1  Male   51-55 years Medical specialist Master degree   Downtown
# 2  Female 41-45 years Non medical staff  Master degree   Downtown
# 4  Male   26-30 years Non medical staff  Bachelor degree Downtown
# 7  Female 46-50 years Medical doctor     Bachelor degree Downtown
# 8  Female 56-60 years Medical doctor     Master degree   Downtown
# 13 Female 41-45 years Nurse              Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 1  No           No          No          No        No           ⋯ No
# 2  No           No          No          No        No           ⋯ No
# 4  No           No          No          No        No           ⋯ No
# 7  No           No          No          No        No           ⋯ No
# 8  No           No          No          No        No           ⋯ No
# 13 No           No          No          No        No           ⋯ No
# ...

# %%
count(dftimenonedata,"X1..Swelling")
count(dftimenonedata,"X2..Redness")
count(dftimenonedata,"X3..Itching")
count(dftimenonedata,"X4..Fever")
count(dftimenonedata,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           361
# 2 Yes           13
#   X2..Redness freq
# 1 No          370
# 2 Yes           4
#   X3..Itching freq
# 1 No          374
#   X4..Fever freq
# 1 No        374
#   X5..Headache freq
# 1 No           358
# 2 Yes           16

# %%
count(dftimenonedata,"X6..Muscle.Pain")
count(dftimenonedata,"X7..Tiredness")
count(dftimenonedata,"X8..Coughing")
count(dftimenonedata,"X9..Diarrhea")
count(dftimenonedata,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              316
# 2 Yes              58
#   X7..Tiredness freq
# 1 No            324
# 2 Yes            50
#   X8..Coughing freq
# 1 No           367
# 2 Yes            7
#   X9..Diarrhea freq
# 1 No           374
#   X10..Nausea.and.vomiting freq
# 1 No                       373
# 2 Yes                        1

# %%
count(dftimenonedata,"X11..Breathlessness")
count(dftimenonedata,"X12..Joint.Pain")
count(dftimenonedata,"X13..Fainted")
count(dftimenonedata,"X14..Anaphylactic.Reaction")
count(dftimenonedata,"X15..Tingling")
count(dftimenonedata,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  373
# 2 Yes                   1
#   X12..Joint.Pain freq
# 1 No              373
# 2 Yes               1
#   X13..Fainted freq
# 1 No           373
# 2 Yes            1
#   X14..Anaphylactic.Reaction freq
# 1 No                         372
# 2 Yes                          2
#   X15..Tingling freq
# 1 No            369
# 2 Yes             5
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       374

# %% [markdown]
# ## < 24 hours

# %%
timebelow24data = data[data$Symptoms.time =="< 24 hours",]
dftimebelow24data <- data.frame(timebelow24data)
dim(timebelow24data)
head(timebelow24data)
# Out:
# [1] 275  22
#    Sex    Age         Professions       Education       Living.Area
# 3  Male   56-60 years Medical doctor    Master degree   Downtown
# 5  Female 31-35 years Medical doctor    Bachelor degree Downtown
# 6  Male   46-50 years Non medical staff Bachelor degree Downtown
# 10 Male   51-55 years Nurse             Master degree   Downtown
# 12 Female 31-35 years Medical doctor    Bachelor degree Downtown
# 16 Male   51-55 years Non medical staff Master degree   Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 3  No           No          No          No        No           ⋯ No
# 5  No           No          No          No        No           ⋯ Yes
# 6  No           No          No          No        No           ⋯ No
# 10 No           No          No          No        No           ⋯ No
# 12 No           No          No          No        No           ⋯ No
# 16 No           No          No          No        No           ⋯ No
# ...

# %%
count(dftimebelow24data,"X1..Swelling")
count(dftimebelow24data,"X2..Redness")
count(dftimebelow24data,"X3..Itching")
count(dftimebelow24data,"X4..Fever")
count(dftimebelow24data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           235
# 2 Yes           40
#   X2..Redness freq
# 1 No          266
# 2 Yes           9
#   X3..Itching freq
# 1 No          275
#   X4..Fever freq
# 1 No        267
# 2 Yes         8
#   X5..Headache freq
# 1 No           197
# 2 Yes           78

# %%
count(dftimebelow24data,"X6..Muscle.Pain")
count(dftimebelow24data,"X7..Tiredness")
count(dftimebelow24data,"X8..Coughing")
count(dftimebelow24data,"X9..Diarrhea")
count(dftimebelow24data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No              122
# 2 Yes             153
#   X7..Tiredness freq
# 1 No            146
# 2 Yes           129
#   X8..Coughing freq
# 1 No           252
# 2 Yes           23
#   X9..Diarrhea freq
# 1 No           268
# 2 Yes            7
#   X10..Nausea.and.vomiting freq
# 1 No                       268
# 2 Yes                        7

# %%
count(dftimebelow24data,"X11..Breathlessness")
count(dftimebelow24data,"X12..Joint.Pain")
count(dftimebelow24data,"X13..Fainted")
count(dftimebelow24data,"X14..Anaphylactic.Reaction")
count(dftimebelow24data,"X15..Tingling")
count(dftimebelow24data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  270
# 2 Yes                   5
#   X12..Joint.Pain freq
# 1 No              269
# 2 Yes               6
#   X13..Fainted freq
# 1 No           275
#   X14..Anaphylactic.Reaction freq
# 1 No                         274
# 2 Yes                          1
#   X15..Tingling freq
# 1 No            251
# 2 Yes            24
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       272
# 2 Yes                        3

# %% [markdown]
# ## 24-72 hours

# %%
time2472data = data[data$Symptoms.time =="24-72 hours",]
dftime2472data <- data.frame(time2472data)
dim(time2472data)
head(time2472data)
# Out:
# [1] 172  22
#    Sex    Age         Professions       Education       Living.Area
# 9  Female 36-40 years Non medical staff Master degree   Downtown
# 11 Female 56-60 years Nurse             Bachelor degree Downtown
# 15 Male   31-35 years Nurse             Bachelor degree Downtown
# 19 Female 56-60 years Nurse             Master degree   Outskirt
# 23 Male   46-50 years Non medical staff Master degree   Outskirt
# 30 Female 36-40 years Nurse             Bachelor degree Downtown
#    X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 9  No           No          No          No        No           ⋯ No
# 11 No           No          No          No        Yes          ⋯ No
# 15 No           No          No          No        Yes          ⋯ Yes
# 19 No           No          No          No        No           ⋯ No
# 23 No           No          No          No        Yes          ⋯ Yes
# 30 Yes          No          No          No        Yes          ⋯ No
# ...

# %%
count(dftime2472data,"X1..Swelling")
count(dftime2472data,"X2..Redness")
count(dftime2472data,"X3..Itching")
count(dftime2472data,"X4..Fever")
count(dftime2472data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           150
# 2 Yes           22
#   X2..Redness freq
# 1 No          169
# 2 Yes           3
#   X3..Itching freq
# 1 No          172
#   X4..Fever freq
# 1 No        168
# 2 Yes         4
#   X5..Headache freq
# 1 No           90
# 2 Yes          82

# %%
count(dftime2472data,"X6..Muscle.Pain")
count(dftime2472data,"X7..Tiredness")
count(dftime2472data,"X8..Coughing")
count(dftime2472data,"X9..Diarrhea")
count(dftime2472data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No               60
# 2 Yes             112
#   X7..Tiredness freq
# 1 No             62
# 2 Yes           110
#   X8..Coughing freq
# 1 No           142
# 2 Yes           30
#   X9..Diarrhea freq
# 1 No           155
# 2 Yes           17
#   X10..Nausea.and.vomiting freq
# 1 No                       168
# 2 Yes                        4

# %%
count(dftime2472data,"X11..Breathlessness")
count(dftime2472data,"X12..Joint.Pain")
count(dftime2472data,"X13..Fainted")
count(dftime2472data,"X14..Anaphylactic.Reaction")
count(dftime2472data,"X15..Tingling")
count(dftime2472data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  168
# 2 Yes                   4
#   X12..Joint.Pain freq
# 1 No              166
# 2 Yes               6
#   X13..Fainted freq
# 1 No           172
#   X14..Anaphylactic.Reaction freq
# 1 No                         172
#   X15..Tingling freq
# 1 No            147
# 2 Yes            25
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       171
# 2 Yes                        1

# %% [markdown]
# ## > 72 hours

# %%
timeabove72data = data[data$Symptoms.time =="> 72 hours",]
dftimeabove72data <- data.frame(timeabove72data)
dim(timeabove72data)
head(timeabove72data)
# Out:
# [1] 19 22
#     Sex    Age         Professions       Education          Living.Area
# 52  Male   26-30 years Nurse             Bachelor degree    Downtown
# 108 Female 31-35 years Non medical staff Senior high school Downtown
# 155 Male   26-30 years Medical doctor    Bachelor degree    Downtown
# 194 Female 46-50 years Non medical staff Bachelor degree    Downtown
# 220 Female 31-35 years Nurse             Bachelor degree    Downtown
# 238 Female 26-30 years Non medical staff Bachelor degree    Downtown
#     X1..Swelling X2..Redness X3..Itching X4..Fever X5..Headache ⋯ X8..Coughing
# 52  No           No          No          No        Yes          ⋯ Yes
# 108 No           No          No          No        Yes          ⋯ No
# 155 No           No          No          No        No           ⋯ No
# 194 No           Yes         No          No        No           ⋯ No
# 220 Yes          No          No          No        Yes          ⋯ No
# ...

# %%
count(dftimeabove72data,"X1..Swelling")
count(dftimeabove72data,"X2..Redness")
count(dftimeabove72data,"X3..Itching")
count(dftimeabove72data,"X4..Fever")
count(dftimeabove72data,"X5..Headache")
# Out:
#   X1..Swelling freq
# 1 No           17
# 2 Yes           2
#   X2..Redness freq
# 1 No          18
# 2 Yes          1
#   X3..Itching freq
# 1 No          19
#   X4..Fever freq
# 1 No        18
# 2 Yes        1
#   X5..Headache freq
# 1 No            9
# 2 Yes          10

# %%
count(dftimeabove72data,"X6..Muscle.Pain")
count(dftimeabove72data,"X7..Tiredness")
count(dftimeabove72data,"X8..Coughing")
count(dftimeabove72data,"X9..Diarrhea")
count(dftimeabove72data,"X10..Nausea.and.vomiting")
# Out:
#   X6..Muscle.Pain freq
# 1 No               9
# 2 Yes             10
#   X7..Tiredness freq
# 1 No             7
# 2 Yes           12
#   X8..Coughing freq
# 1 No           13
# 2 Yes           6
#   X9..Diarrhea freq
# 1 No           17
# 2 Yes           2
#   X10..Nausea.and.vomiting freq
# 1 No                       18
# 2 Yes                       1

# %%
count(dftimeabove72data,"X11..Breathlessness")
count(dftimeabove72data,"X12..Joint.Pain")
count(dftimeabove72data,"X13..Fainted")
count(dftimeabove72data,"X14..Anaphylactic.Reaction")
count(dftimeabove72data,"X15..Tingling")
count(dftimeabove72data,"X16..Swollen.Lymph.Nodes")
# Out:
#   X11..Breathlessness freq
# 1 No                  18
# 2 Yes                  1
#   X12..Joint.Pain freq
# 1 No              19
#   X13..Fainted freq
# 1 No           19
#   X14..Anaphylactic.Reaction freq
# 1 No                         19
#   X15..Tingling freq
# 1 No            15
# 2 Yes            4
#   X16..Swollen.Lymph.Nodes freq
# 1 No                       19
