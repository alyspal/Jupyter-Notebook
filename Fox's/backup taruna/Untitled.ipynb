# %%
train = pd.read_csv('bri hackathon/train.csv')
test = pd.read_csv('bri hackathon/test.csv')
sample_submission = pd.read_csv('bri hackathon/sample_submission.csv')

# %%
profile1 = ProfileReport(train)
profile2 = ProfileReport(test)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(train.corr(),annot =True,linewidth=(0.8))
# Out:
# <AxesSubplot:>

# %%
a = pd.crosstab(train['Best Performance'],train['Employee_status'])

# %%
a
# Out:
# Employee_status   Contract  Permanent
# Best Performance
# 0                     2055      17282
# 1                        0       2668

# %%
a = pd.crosstab(train['Best Performance'],train['job_level'])

# %%
a
# Out:
# job_level         JG03   JG04  JG05  JG06
# Best Performance
# 0                 1977  16631   722     7
# 1                   13   2527   128     0

# %%
a = pd.crosstab(train['Best Performance'],train['person_level'])

# %%
a['PG01']
# Out:
# Best Performance
# 0    1937
# 1       9
# Name: PG01, dtype: int64

# %%
a = pd.crosstab(train['Best Performance'],train['Employee_type'])

# %%
a
# Out:
# Employee_type     RM_type_A  RM_type_B  RM_type_C
# Best Performance
# 0                      9474       9192        659
# 1                      1556       1019         93

# %%
a = pd.crosstab(train['Best Performance'],train['gender'])

# %%
a
# Out:
# gender            Female   Male
# Best Performance
# 0                   4954  14383
# 1                    716   1952

# %%
a = pd.crosstab(train['Best Performance'],train['marital_status_maried(Y/N)'])

# %%
a
# Out:
# marital_status_maried(Y/N)     N      Y
# Best Performance
# 0                           5859  13478
# 1                            487   2181

# %%
a = pd.crosstab(train['Best Performance'],train['achievement_target_1'])
a
# Out:
# achievement_target_1  Pencapaian 100%-150%  Pencapaian 50%-100%  \
# Best Performance
# 0                                      421                 1326
# 1                                       64                  205
#
# achievement_target_1  Pencapaian < 50%  Pencapaian > 1.5  \
# Best Performance
# 0                                  150                46
# 1                                   25                 3
#
# achievement_target_1  Tidak diberikan target  achiev_100%-150%  \
# Best Performance
# 0                                        149              2159
# 1                                         29               360
#
# achievement_target_1  achiev_50%-100%  achiev_< 50%  achiev_> 1.5
# Best Performance
# 0                                6496          1750           505
# 1                                1183           315            92

# %%
a = pd.crosstab(train['Best Performance'],train['achievement_target_2'])
a
# Out:
# achievement_target_2  Pencapaian 100%-150%  Pencapaian 50%-100%  \
# Best Performance
# 0                                      126                  429
# 1                                       19                   55
#
# achievement_target_2  Pencapaian < 50%  Pencapaian > 1.5  \
# Best Performance
# 0                                 1327                61
# 1                                  215                10
#
# achievement_target_2  Tidak diberikan target  achiev_100%-150%  \
# Best Performance
# 0                                        155               806
# 1                                         21               119
#
# achievement_target_2  achiev_50%-100%  achiev_< 50%  achiev_> 1.5
# Best Performance
# 0                                2001          7295           802
# 1                                 365          1320           152

# %%
a = pd.crosstab(train['Best Performance'],train['achievement_target_3'])
a
# Out:
# achievement_target_3  not reached  not_reached  reached
# Best Performance
# 0                            3583           13     9406
# 1                             692            5     1579

# %%
a = pd.crosstab(train['Best Performance'],train['Education_level'])
a
# Out:
# Education_level   level_0  level_1  level_2  level_3  level_4  level_5
# Best Performance
# 0                      15      158        8     2481    13566       54
# 1                       1       34        0      323     1747       10

# %%
a = pd.crosstab(train['Best Performance'],train['achievement_target_1'])
a
# Out:
# achievement_target_1  Pencapaian 100%-150%  Pencapaian 50%-100%  \
# Best Performance
# 0                                      421                 1326
# 1                                       64                  205
#
# achievement_target_1  Pencapaian < 50%  Pencapaian > 1.5  \
# Best Performance
# 0                                  150                46
# 1                                   25                 3
#
# achievement_target_1  Tidak diberikan target  achiev_100%-150%  \
# Best Performance
# 0                                        149              2159
# 1                                         29               360
#
# achievement_target_1  achiev_50%-100%  achiev_< 50%  achiev_> 1.5
# Best Performance
# 0                                6496          1750           505
# 1                                1183           315            92
