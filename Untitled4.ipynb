# %%
install.packages("car")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘matrixStats’, ‘RcppArmadillo’, ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘conquer’, ‘sp’, ‘openxlsx’, ‘minqa’, ‘nloptr’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘maptools’, ‘rio’, ‘lme4’

# %%
rata2makanan <- read.csv('makanan20132019.csv')
head(rata2makanan)
# Out:
#   Makanan        X2013  X2014  X2015  X2016  X2017  X2018  X2019
# 1 Padi-padian    57 956 60 235 66 929 64 566 61 455 66 936 64 961
# 2 Umbi-umbian    3 151  3 566  4 470  5 057  5 764  5 623  5 886
# 3 Ikan           28 356 31 849 32 041 33 620 40 478 43 352 45 304
# 4 Daging         13 252 14 980 18 048 20 526 24 987 23 006 24 783
# 5 Telur dan susu 21 540 23 923 26 616 28 025 29 357 32 196 32 435
# 6 Sayur-sayuran  31 158 30 068 27 365 34 505 42 397 39 664 37 898

# %%
rata2bknmakanan <- read.csv('bukanmakanan20132019.csv')
head(rata2bknmakanan)
# Out:
#   Bukan.Makanan                           X2013   X2014   X2015   X2016
# 1 Perumahan, bahan bakar, penerangan, air 142 088 161 059 234 139 251 692
# 2 Aneka barang dan jasa                   78 219  95 745  63 119  67 221
# 3 Biaya pendidikan                        27 875  30 408  29 926  32 278
# 4 Biaya kesehatan                         24 169  25 520  21 392  22 699
# 5 Pakaian, alas kaki, dan tutup kepala    14 527  14 818  25 378  28 869
# 6 Barang yang tahan lama                  37 863  34 565  47 800  44 974
#   X2017   X2018   X2019
# 1 249 644 284 442 297 019
# 2 62 801  74 792  144 517
# 3 35 358  34 953  36 135
# 4 27 006  29 642  30 086
# 5 31 187  32 861  35 303
# 6 54 005  57 789  58 764

# %%
#Transform Makanan
mkn<-data.frame(rata2makanan)
padi<-mkn[1,]
umbi<-mkn[2,]
ikan<-mkn[3,]
daging<-mkn[4,]
telursusu<-mkn[5,]
sayur<-mkn[6,]

# %%
#Transform Bukan Makanan
bknmkn<-data.frame(rata2bknmakanan)
rumahdll<-bknmkn[1,]
barangjasa<-bknmkn[2,]
pend<-bknmkn[3,]
sehat<-bknmkn[4,]
pakaian<-bknmkn[5,]
brgtahanlama<-bknmkn[6,]

# %%
levenetest
# Out:
#   Bukan.Makanan          X2013  X2014  X2015  X2016  X2017  X2018  X2019
# 6 Barang yang tahan lama 37 863 34 565 47 800 44 974 54 005 57 789 58 764
